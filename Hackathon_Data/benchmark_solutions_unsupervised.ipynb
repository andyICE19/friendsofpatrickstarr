# %% [markdown]
# # Automated metadata matching
# Life sciences (LS)/ Clinical research institutes (academic research institutes, pharma companies, hospitals, clinics etc.) across the world are producing large volumes of data from patients. This can range from clinical information such as diagnostic/prognostic data, omic data such as genetic/proteomic/epigenetic screens, pathological data such as MRI scans etc. One of the main objectives in LS research (both academic and industrial) is to gain actionable insights from these data sets, that goes beyond the diagnosis/prognosis of a (group of) patient(s) and provides a deeper understanding of the diseases, as well as shine lights on new therapeutic options. It is becoming apparent, that to gain actionable insights from LS data sets, we need data from a large number of patients. This is achievable, if we could merge datasets from various institutes, which is turning out to be hugely challenging task, simply because different institutes use different standards, units, nomenclature etc. to store data. <br><br>
#
# For instance, patient's age is a common clinical parameter recorded by almost all organisations. One institute can name the variable that records patients’ age as 'patient age', another can name the same variable as 'age', others can name it as 'age at diagnosis', 'days since birth', 'years since birth' etc. The values can also be in days, months, years etc. Therefore, to combine data from many institutes (and sometimes within same institutes), it's essential to understand that all of the above variables are recording the same thing, i.e. patient's age, also we need to make sure that the units (days, months, years) of measuring age are homogenised at the time of integration. <br><br>
#
# To assist in the above process the National Cancer Institute (NCI) created the concept of CDE (common data element). See https://cdebrowser.nci.nih.gov/cdebrowserClient/cdeBrowser.html#/search for more details. A big data dump of about 69000 CDE elements are provided in 'cde_database\full_database' folder in XML format, if you want to further explore. They provide a standard format of representing Life Science's data. This gives us standard variable name, the permissible values , units etc. for each of these clinical parameters. Some research organizations are following this standard, but vast majority aren't. Additionally, there is huge amount of data produced until now which are not standardized using CDEs. <br><br>
#
# To be able to integrate data from various institutes, we need to be able to match the variable names in the clinical datasets to the corresponding CDE elements. Currently, there is a drive for developing ML/AI algorithms to achieve this.<br><br>
#
#
# The code below is an initial attempt in this direction. In summary, it tries to match the variables names (generally the column headers in a clinical data file) and values (the column values) of the clinical parameters in a dataset, to the long variable names, and permissible values of the CDE elements. The objective is to find the CDE elements that closely match the each clinical parameter name (i.e. the column header). To do the the following steps are performed: <br><br>
#
# 1. Converted selected aspectes (e.g. long_name, permissible_values etc.) of all CDE elements into numerical vectors using a word embedding model which itself was trained on these data.
#
# 2. Coverted the clinical parameter names (headers) and values into numerical vector using the same word embedding model as above.
#
# 3. The vectors from the clinical data can be matched to CDE vectors in a few different ways: <br>
#    (a) One way is to use unsupervised learning, fit a Nearest Neighbour model to the CDE vectors, and look for the nearest neighbors of each clinical parameter using this model.
#    (b) Another way is to use supervised learning: Create feature vectors for all possible pairs of clinical parameters and CDE elements, consider the true pairs as positive class (target =1) and the remaining pairs as negative class (target = 0). Train classifiers to this data and use the classifier to evaluate new clinical parameters.
#
#
# See more details below.

# %% [markdown]
# ## Install custom benchmark solutions libraries

# %%
# !pip install cde_modelling_tools/.
# Out:
# Processing c:\users\tapes\onedrive\documents\hackathon_documents_v1\cde_modelling_tools
# Building wheels for collected packages: cde-data-modeller
#   Building wheel for cde-data-modeller (setup.py): started
#   Building wheel for cde-data-modeller (setup.py): finished with status 'done'
#   Created wheel for cde-data-modeller: filename=cde_data_modeller-0.0.1-py3-none-any.whl size=15963 sha256=0e62489060126c4b323dbe10e20e84c0e7ddd266148121079995fa95552d43fc
#   Stored in directory: C:\Users\tapes\AppData\Local\Temp\pip-ephem-wheel-cache-in7obrn5\wheels\d1\d6\de\83b2166f12e4abb68ba736ffc7f9cfb70c0093eda89b5f882b
# Successfully built cde-data-modeller
# Installing collected packages: cde-data-modeller
#   Attempting uninstall: cde-data-modeller
#     Found existing installation: cde-data-modeller 0.0.1
#     Uninstalling cde-data-modeller-0.0.1:
#       Successfully uninstalled cde-data-modeller-0.0.1
# Successfully installed cde-data-modeller-0.0.1

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd

import json
import numpy as np
import random
import mlflow
from cde_modelling.modelling import CDE_data_modeller as cdm
from cde_modelling.parsing import TCGA_data_parser as tdp
from cde_modelling.utils import Accuracy_calculations as ac
import pickle 
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\mark.kirby\Anaconda3\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %% [markdown]
# ## File paths

# %%
clinical_data_files_dir = 'tcga_training_data/'

clinical_data_test_dir = 'tcga_test_data/'

cde_database_file = 'cde_database/combined_small_dataset.json'

parameter_file = 'params_unsupervised.json'

model_dir = 'models/'

test_gold_standard = 'gold_standard/test_gs.json'

# %% [markdown]
# ## Load model parameters

# %%
# read model parameters
params = {}

with open(parameter_file,'r') as file:
    params = json.load(file)

# %% [markdown]
# ## Create a fasttext model for the CDE database and index the individual CDE elements in the database
#
# Fasttext is a word embedding algorithm developed by FaceBook. Given a corpus, it creates a model that tries to predict if a pair of words appear in the same context. The model first converts the words to a numeric vector which are used as features for the above prediction. We are interested in the feature generation part, i.e. the part which converts words to numeric vectors. For more information on the FastText model see https://radimrehurek.com/gensim/models/fasttext.html.
#
# ### FastText model training:
#
# To train a FastText model we first extracted the long_name and permissible_values of each CDE elements. These were then parseed and cleaned (lower cased, alphanumeric character only, splitted into bag of words). The preprocessed long names and permissible values of all CDE element was considered as the training corpus for the FastText model. The corpus was then used to train A FastText model. The parameters for the model are in the above json file. The trained model is then used to index the CDE elements (i.e. create numeric vectors representing each CDE). We created two sets of vectors for CDE elements, one for the long_names and the other for permissible values. We alo extracted the data_type information for each CDE elements. Below is an example. Let's assume that the following is a (oversimplified) CDE element .
# CDE_element:
# {
# 'public_id': 1234
# 'long_name': 'received radiotherapy'
# ..............
# 'permissible_values': ['yes','no']
# }.
#
# To index the above CDE, we performed the following:
#
# 1. Vectorized the long_name entry (i.e. 'received radiotherapy') using the FastText model. To do that, we vectorized each word (i.e. 'received' and 'radiotherapy') of the long name entry separately. The vectors were then normalized by their L2 norms and averaged. Say for example, the long_name vector is [0.1, 0.345].
#
# 2. Vectorized the 'permissible_values' entry (i.e. 'yes', 'no') using the FastText model. To do that, we vectorized each word (i.e. 'received' and 'radiotherapy') in the permissible_values entry separately. The vectors were then normalized by their L2 norms and averaged.Say for example, the permissible vector is [0.981, 0.233].
#
# 3. We identified whether the permissible values are string or numbers. Note, that for the benchmark solution, we kept this simple. But for the hackathon, the participants can conder more grannular data type for example, string, binary, float, int long etc.
#
#
# Combination of the above is used to numerically represent (index) each CDE. The class CDE_data_modeller, in package cde_modelling_tools does the above. Pparticipants should explore using other entries in the CDE data fields to improve their chances of finding a match.
#
# The CDE_data_modeller class not only creates the word embedding models and index (vectorize) the CDE data elements, it can also save and load pretrained models and indexes.

# %%
cde_data_modellers = cdm.CDE_data_modeller(cde_database_file, params)
cde_data_modellers.create_model_and_cde_indexes()
# cde_data_modellers.save_model_and_indexes(model_dir+'fasttext/')
# Out:
# Loading CDE database... please wait
# Took 0.003225  minutes to load CDE database..
# Starting model training ...
#  19%|██████████████▍                                                              | 934/4991 [00:00<00:00, 9272.32it/s]
# Model training took 6.161290 minutes
# Start converting descriptors to vectors
# 100%|████████████████████████████████████████████████████████████████████████████| 4991/4991 [00:00<00:00, 9131.99it/s]
#   0%|                                                                                         | 0/4991 [00:00<?, ?it/s]C:\Users\mark.kirby\Anaconda3\lib\site-packages\cde_modelling\modelling\CDE_data_modeller.py:498: RuntimeWarning: invalid value encountered in true_divide
#   vector = vector/len(sentence)
# Took 0.009391 minutes to vectorize the dataset
# Start converting descriptors to vectors
# 100%|████████████████████████████████████████████████████████████████████████████| 4991/4991 [00:00<00:00, 5207.62it/s]
# Took 0.016206 minutes to vectorize the dataset

# %% [markdown]
# ## Load a pretrained FastText model and saved indexes for CDE elements

# %%
cde_data_modellers = cdm.CDE_data_modeller(cde_database_file, params)
cde_data_modellers.load_model_and_cde_indexes(model_dir+'fasttext/')
# Out:
# Loading CDE database... please wait
# Took 0.002643  minutes to load CDE database..

# %% [markdown]
# ## Load and parse training data
#
# The training data are a set of clinical data files which records cinical information of patients, e.g. gender, age, disease_type, disease_sub_type, treatment received etc. It's in table format, where the rows represent patients and the columns represent colinical parameters. In case of the training data, the CDE data element corrsponding to each clinical parameter is provided. This information can be used to train machine learning algorithms to predict CDE elements for new clinical parameters.

# %%
tdpr = tdp.TCGA_data_processor(clinical_data_files_dir,True )
tcga_data = tdpr.get_parsed_data()
# Out:
#   2%|█▏                                                                                | 3/200 [00:00<00:08, 22.61it/s]
#  Processing clinical metadata.. please wait..
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:06<00:00, 29.38it/s]

# %% [markdown]
# The parser returns three types of information for each clinical parameter.
#
# 1. The name of the parameter (e.g. age, gender, etc.)
# 2. List of values for each parameters (except id columns, continuous variabales etc.)
# 3. Data type of the values. For instance, data type of 'age' is 'number', data type of gender = 'string'.
# 4. A dictionary containing clinical parameters and it's corresponding
#
# See the parsed data below.

# %%
tcga_data.keys()
# Out:
# dict_keys(['headers', 'values', 'value_type', 'gold_standard'])

# %%
tcga_data['headers'] # tcga_data['values'] / tcga_data['value_type'] / tcga_data['gold_standard']
# Out:
# {'bcr_patient_barcode': ['bcr', 'patient', 'barcode'],
#  'bcr_drug_barcode': ['bcr', 'drug', 'barcode'],
#  'bcr_drug_uuid': ['bcr', 'drug', 'uuid'],
#  'form_completion_date': ['form', 'completion', 'date'],
#  'pharmaceutical_therapy_drug_name': ['pharmaceutical',
#   'therapy',
#   'drug',
#   'name'],
#  'clinical_trial_drug_classification': ['clinical',
#   'trial',
#   'drug',
#   'classification'],
#  'pharmaceutical_therapy_type': ['pharmaceutical', 'therapy', 'type'],
#  'pharmaceutical_tx_started_days_to': ['pharmaceutical',
#   'tx',
#   'started',
#   'days',
#   'to'],
#  'pharmaceutical_tx_ongoing_indicator': ['pharmaceutical',
#   'tx',
#   'ongoing',
#   'indicator'],
#  'pharmaceutical_tx_ended_days_to': ['pharmaceutical',
#   'tx',
#   'ended',
#   'days',
#   'to'],
#  'treatment_best_response': ['treatment', 'best', 'response'],
#  'days_to_stem_cell_transplantation': ['days',
#   'to',
#   'stem',
#   'cell',
#   'transplantation'],
#  'number_cycles': ['number', 'cycles'],
#  'pharm_regimen': ['pharm', 'regimen'],
#  'pharm_regimen_other': ['pharm', 'regimen', 'other'],
#  'prescribed_dose': ['prescribed', 'dose'],
#  'prescribed_dose_units': ['prescribed', 'dose', 'units'],
#  'regimen_indication': ['regimen', 'indication'],
#  'regimen_indication_notes': ['regimen', 'indication', 'notes'],
#  'regimen_number': ['regimen', 'number'],
#  'route_of_administration': ['route', 'of', 'administration'],
#  'stem_cell_transplantation': ['stem', 'cell', 'transplantation'],
#  'stem_cell_transplantation_type': ['stem', 'cell', 'transplantation', 'type'],
#  'therapy_type_notes': ['therapy', 'type', 'notes'],
#  'total_dose': ['total', 'dose'],
#  'total_dose_units': ['total', 'dose', 'units'],
#  'tx_on_clinical_trial': ['tx', 'on', 'clinical', 'trial'],
#  'pharma_adjuvant_cycles_count': ['pharma', 'adjuvant', 'cycles', 'count'],
#  'pharma_type_other': ['pharma', 'type', 'other'],
#  'pharmaceutical_tx_dose_units': ['pharmaceutical', 'tx', 'dose', 'units'],
#  'pharmaceutical_tx_total_dose_units': ['pharmaceutical',
#   'tx',
#   'total',
#   'dose',
#   'units'],
#  'therapy_regimen': ['therapy', 'regimen'],
#  'therapy_regimen_other': ['therapy', 'regimen', 'other'],
#  'bcr_followup_barcode': ['bcr', 'followup', 'barcode'],
#  'bcr_followup_uuid': ['bcr', 'followup', 'uuid'],
#  'followup_reason': ['followup', 'reason'],
#  'followup_lost_to': ['followup', 'lost', 'to'],
#  'radiation_treatment_adjuvant': ['radiation', 'treatment', 'adjuvant'],
#  'pharmaceutical_tx_adjuvant': ['pharmaceutical', 'tx', 'adjuvant'],
#  'treatment_outcome_first_course': ['treatment', 'outcome', 'first', 'course'],
#  'vital_status': ['vital', 'status'],
#  'last_contact_days_to': ['last', 'contact', 'days', 'to'],
#  'death_days_to': ['death', 'days', 'to'],
#  'tumor_status': ['tumor', 'status'],
#  'new_tumor_event_dx_indicator': ['new', 'tumor', 'event', 'dx', 'indicator'],
#  'treatment_outcome_at_tcga_followup': ['treatment',
#   'outcome',
#   'at',
#   'tcga',
#   'followup'],
#  'ecog_score': ['ecog', 'score'],
#  'karnofsky_score': ['karnofsky', 'score'],
#  'performance_status_timing': ['performance', 'status', 'timing'],
#  'new_tumor_event_dx_days_to': ['new', 'tumor', 'event', 'dx', 'days', 'to'],
#  'new_tumor_event_site': ['new', 'tumor', 'event', 'site'],
#  'new_tumor_event_site_other': ['new', 'tumor', 'event', 'site', 'other'],
#  'new_tumor_event_type': ['new', 'tumor', 'event', 'type'],
#  'new_tumor_event_dx_evidence': ['new', 'tumor', 'event', 'dx', 'evidence'],
#  'new_tumor_event_radiation_tx': ['new', 'tumor', 'event', 'radiation', 'tx'],
#  'new_tumor_event_pharmaceutical_tx': ['new',
#   'tumor',
#   'event',
#   'pharmaceutical',
#   'tx'],
#  'additional_surgery_locoregional_procedure': ['additional',
#   'surgery',
#   'locoregional',
#   'procedure'],
#  'new_tumor_event_surgery_days_to_loco': ['new',
#   'tumor',
#   'event',
#   'surgery',
#   'days',
#   'to',
#   'loco'],
#  'new_tumor_event_surgery_days_to_met': ['new',
#   'tumor',
#   'event',
#   'surgery',
#   'days',
#   'to',
#   'met'],
#  'new_tumor_event_surgery_met': ['new', 'tumor', 'event', 'surgery', 'met'],
#  'targeted_molecular_therapy': ['targeted', 'molecular', 'therapy'],
#  'new_tumor_event_surgery': ['new', 'tumor', 'event', 'surgery'],
#  'days_to_performance_status_assessment': ['days',
#   'to',
#   'performance',
#   'status',
#   'assessment'],
#  'new_neoplasm_event_type': ['new', 'neoplasm', 'event', 'type'],
#  'patient_death_reason': ['patient', 'death', 'reason'],
#  'new_tumor_event_site_surgery': ['new', 'tumor', 'event', 'site', 'surgery'],
#  'days_to_new_tumor_event_additional_surgery_procedure': ['days',
#   'to',
#   'new',
#   'tumor',
#   'event',
#   'additional',
#   'surgery',
#   'procedure'],
#  'new_neoplasm_event_occurrence_anatomic_site': ['new',
#   'neoplasm',
#   'event',
#   'occurrence',
#   'anatomic',
#   'site'],
#  'new_neoplasm_occurrence_anatomic_site_text': ['new',
#   'neoplasm',
#   'occurrence',
#   'anatomic',
#   'site',
#   'text'],
#  'new_tumor_event_additional_surgery_procedure': ['new',
#   'tumor',
#   'event',
#   'additional',
#   'surgery',
#   'procedure'],
#  'progression_determined_by': ['progression', 'determined', 'by'],
#  'residual_disease_post_new_tumor_event_margin_status': ['residual',
#   'disease',
#   'post',
#   'new',
#   'tumor',
#   'event',
#   'margin',
#   'status'],
#  'new_tumor_event_dx_method_other': ['new',
#   'tumor',
#   'event',
#   'dx',
#   'method',
#   'other'],
#  'additional_pharmaceutical_therapy': ['additional',
#   'pharmaceutical',
#   'therapy'],
#  'cause_of_death': ['cause', 'of', 'death'],
#  'cause_of_death_source': ['cause', 'of', 'death', 'source'],
#  'days_to_biochemical_recurrence_first': ['days',
#   'to',
#   'biochemical',
#   'recurrence',
#   'first'],
#  'progression_after_hormone_tx': ['progression', 'after', 'hormone', 'tx'],
#  'progression_after_hormone_tx_type': ['progression',
#   'after',
#   'hormone',
#   'tx',
#   'type'],
#  'days_to_biochemical_recurrence_second': ['days',
#   'to',
#   'biochemical',
#   'recurrence',
#   'second'],
#  'days_to_biochemical_recurrence_third': ['days',
#   'to',
#   'biochemical',
#   'recurrence',
#   'third'],
#  'nte_er_status': ['nte', 'er', 'status'],
#  'nte_er_status_ihc__positive': ['nte', 'er', 'status', 'ihc', 'positive'],
#  'nte_er_ihc_intensity_score': ['nte', 'er', 'ihc', 'intensity', 'score'],
#  'nte_er_positivity_other_scale': ['nte',
#   'er',
#   'positivity',
#   'other',
#   'scale'],
#  'nte_er_positivity_define_method': ['nte',
#   'er',
#   'positivity',
#   'define',
#   'method'],
#  'nte_pr_status_by_ihc': ['nte', 'pr', 'status', 'by', 'ihc'],
#  'nte_pr_status_ihc__positive': ['nte', 'pr', 'status', 'ihc', 'positive'],
#  'nte_pr_ihc_intensity_score': ['nte', 'pr', 'ihc', 'intensity', 'score'],
#  'nte_pr_positivity_other_scale': ['nte',
#   'pr',
#   'positivity',
#   'other',
#   'scale'],
#  'nte_pr_positivity_define_method': ['nte',
#   'pr',
#   'positivity',
#   'define',
#   'method'],
#  'nte_her2_status': ['nte', 'her2', 'status'],
#  'nte_her2_status_ihc__positive': ['nte', 'her2', 'status', 'ihc', 'positive'],
#  'nte_her2_positivity_ihc_score': ['nte',
#   'her2',
#   'positivity',
#   'ihc',
#   'score'],
#  'nte_her2_positivity_other_scale': ['nte',
#   'her2',
#   'positivity',
#   'other',
#   'scale'],
#  'nte_her2_positivity_method': ['nte', 'her2', 'positivity', 'method'],
#  'nte_her2_fish_status': ['nte', 'her2', 'fish', 'status'],
#  'nte_her2_signal_number': ['nte', 'her2', 'signal', 'number'],
#  'nte_cent_17_signal_number': ['nte', 'cent', '17', 'signal', 'number'],
#  'her2_cent17_counted_cells_count': ['her2',
#   'cent17',
#   'counted',
#   'cells',
#   'count'],
#  'nte_cent_17_her2_ratio': ['nte', 'cent', '17', 'her2', 'ratio'],
#  'nte_cent17_her2_other_scale': ['nte', 'cent17', 'her2', 'other', 'scale'],
#  'nte_her2_fish_define_method': ['nte', 'her2', 'fish', 'define', 'method'],
#  'cent17_copy_number': ['cent17', 'copy', 'number'],
#  'days_to_additional_surgery_locoregional_procedure': ['days',
#   'to',
#   'additional',
#   'surgery',
#   'locoregional',
#   'procedure'],
#  'days_to_additional_surgery_metastatic_procedure': ['days',
#   'to',
#   'additional',
#   'surgery',
#   'metastatic',
#   'procedure'],
#  'days_to_last_known_alive': ['days', 'to', 'last', 'known', 'alive'],
#  'er_ihc_score': ['er', 'ihc', 'score'],
#  'er_positivity_method': ['er', 'positivity', 'method'],
#  'er_positivity_scale_other': ['er', 'positivity', 'scale', 'other'],
#  'er_status_by_ihc': ['er', 'status', 'by', 'ihc'],
#  'er_status_ihc_Percent_Positive': ['er',
#   'status',
#   'ihc',
#   'percent',
#   'positive'],
#  'her2_and_cent17_cells_count': ['her2', 'and', 'cent17', 'cells', 'count'],
#  'her2_and_cent17_scale_other': ['her2', 'and', 'cent17', 'scale', 'other'],
#  'her2_cent17_ratio': ['her2', 'cent17', 'ratio'],
#  'her2_copy_number': ['her2', 'copy', 'number'],
#  'her2_fish_method': ['her2', 'fish', 'method'],
#  'her2_fish_status': ['her2', 'fish', 'status'],
#  'her2_ihc_percent_positive': ['her2', 'ihc', 'percent', 'positive'],
#  'her2_ihc_score': ['her2', 'ihc', 'score'],
#  'her2_positivity_method_text': ['her2', 'positivity', 'method', 'text'],
#  'her2_positivity_scale_other': ['her2', 'positivity', 'scale', 'other'],
#  'her2_status_by_ihc': ['her2', 'status', 'by', 'ihc'],
#  'pr_positivity_define_method': ['pr', 'positivity', 'define', 'method'],
#  'pr_positivity_ihc_intensity_score': ['pr',
#   'positivity',
#   'ihc',
#   'intensity',
#   'score'],
#  'pr_positivity_scale_other': ['pr', 'positivity', 'scale', 'other'],
#  'pr_status_by_ihc': ['pr', 'status', 'by', 'ihc'],
#  'pr_status_ihc_percent_positive': ['pr',
#   'status',
#   'ihc',
#   'percent',
#   'positive'],
#  'history_menopausal_hormone_therapy': ['history',
#   'menopausal',
#   'hormone',
#   'therapy'],
#  'history_hormonal_contraceptives_use': ['history',
#   'hormonal',
#   'contraceptives',
#   'use'],
#  'history_tamoxifen_use': ['history', 'tamoxifen', 'use'],
#  'hypertension_diagnosis': ['hypertension', 'diagnosis'],
#  'diabetes_diagnosis_indicator': ['diabetes', 'diagnosis', 'indicator'],
#  'pregnancies_full_term_count': ['pregnancies', 'full', 'term', 'count'],
#  'history_colorectal_cancer': ['history', 'colorectal', 'cancer'],
#  'new_tumor_event_procedure': ['new', 'tumor', 'event', 'procedure'],
#  'new_tumor_event_procedure_other': ['new',
#   'tumor',
#   'event',
#   'procedure',
#   'other'],
#  'cause_of_death_other': ['cause', 'of', 'death', 'other'],
#  'performance_status_other_timing': ['performance',
#   'status',
#   'other',
#   'timing'],
#  'rt_tx_reason_not_completed': ['rt', 'tx', 'reason', 'not', 'completed'],
#  'rt_tx_reason_not_completed_other': ['rt',
#   'tx',
#   'reason',
#   'not',
#   'completed',
#   'other'],
#  'brachytherapy_type': ['brachytherapy', 'type'],
#  'brachytherapy_type_other': ['brachytherapy', 'type', 'other'],
#  'brachytherapy_total_dose_point_a': ['brachytherapy',
#   'total',
#   'dose',
#   'point',
#   'a'],
#  'radiation_therapy_xrt_type': ['radiation', 'therapy', 'xrt', 'type'],
#  'radiation_type_other': ['radiation', 'type', 'other'],
#  'rt_tx_total_dose_to_pelvis': ['rt', 'tx', 'total', 'dose', 'to', 'pelvis'],
#  'radiation_therapy_dose_paraaortic_nodes': ['radiation',
#   'therapy',
#   'dose',
#   'paraaortic',
#   'nodes'],
#  'chemo_concurrent_reason_not_given': ['chemo',
#   'concurrent',
#   'reason',
#   'not',
#   'given'],
#  'chemo_concurrent_reason_not_other': ['chemo',
#   'concurrent',
#   'reason',
#   'not',
#   'other'],
#  'chemo_concurrent_type': ['chemo', 'concurrent', 'type'],
#  'chemo_concurrent_type_other': ['chemo', 'concurrent', 'type', 'other'],
#  'chemo_concurrent_dose': ['chemo', 'concurrent', 'dose'],
#  'chemo_concurrent_course': ['chemo', 'concurrent', 'course'],
#  'chemo_concurrent_fractions_total': ['chemo',
#   'concurrent',
#   'fractions',
#   'total'],
#  'new_tumor_event_pathologic_dx_other': ['new',
#   'tumor',
#   'event',
#   'pathologic',
#   'dx',
#   'other'],
#  'brachytherapy_status': ['brachytherapy', 'status'],
#  'days_to_brachytherapy_begin_occurrence': ['days',
#   'to',
#   'brachytherapy',
#   'begin',
#   'occurrence'],
#  'days_to_brachytherapy_end_occurrence': ['days',
#   'to',
#   'brachytherapy',
#   'end',
#   'occurrence'],
#  'days_to_chemotherapy_end': ['days', 'to', 'chemotherapy', 'end'],
#  'days_to_chemotherapy_start': ['days', 'to', 'chemotherapy', 'start'],
#  'days_to_radiation_therapy_end': ['days',
#   'to',
#   'radiation',
#   'therapy',
#   'end'],
#  'days_to_radiation_therapy_start': ['days',
#   'to',
#   'radiation',
#   'therapy',
#   'start'],
#  'radiation_adjuvant_indicator': ['radiation', 'adjuvant', 'indicator'],
#  'radiation_therapy_status': ['radiation', 'therapy', 'status'],
#  'targeted_molecular_therapy.1': ['targeted', 'molecular', 'therapy.1'],
#  'new_tumor_event_dx_confirmed_by': ['new',
#   'tumor',
#   'event',
#   'dx',
#   'confirmed',
#   'by'],
#  'new_tumor_event_histo_progression': ['new',
#   'tumor',
#   'event',
#   'histo',
#   'progression'],
#  'new_tumor_event_histo_progress_type': ['new',
#   'tumor',
#   'event',
#   'histo',
#   'progress',
#   'type'],
#  'new_tumor_event_histo_progress_other': ['new',
#   'tumor',
#   'event',
#   'histo',
#   'progress',
#   'other'],
#  'new_tumor_event_node_site': ['new', 'tumor', 'event', 'node', 'site'],
#  'new_tumor_event_node_site_other': ['new',
#   'tumor',
#   'event',
#   'node',
#   'site',
#   'other'],
#  'new_tumor_event_tx': ['new', 'tumor', 'event', 'tx'],
#  'i_131_radiation_first_tx_method': ['i',
#   '131',
#   'radiation',
#   'first',
#   'tx',
#   'method'],
#  'i_131_radiation_first_tx_dose': ['i',
#   '131',
#   'radiation',
#   'first',
#   'tx',
#   'dose'],
#  'i_131_radiation_subsequent_tx': ['i',
#   '131',
#   'radiation',
#   'subsequent',
#   'tx'],
#  'i_131_radiation_tx_cumulative_dose': ['i',
#   '131',
#   'radiation',
#   'tx',
#   'cumulative',
#   'dose'],
#  'radiation_therapy_xrt_method_prep': ['radiation',
#   'therapy',
#   'xrt',
#   'method',
#   'prep'],
#  'radiation_therapy_xrt_dose': ['radiation', 'therapy', 'xrt', 'dose'],
#  'radiation_therapy_xrt_sensitizers': ['radiation',
#   'therapy',
#   'xrt',
#   'sensitizers'],
#  'subsequent_known_primaries': ['subsequent', 'known', 'primaries'],
#  'new_tumor_event_surgery_days_to': ['new',
#   'tumor',
#   'event',
#   'surgery',
#   'days',
#   'to'],
#  'new_tumor_event_met_site': ['new', 'tumor', 'event', 'met', 'site'],
#  'new_tumor_event_met_site_other': ['new',
#   'tumor',
#   'event',
#   'met',
#   'site',
#   'other'],
#  'new_tumor_event_melanoma_location': ['new',
#   'tumor',
#   'event',
#   'melanoma',
#   'location'],
#  'new_tumor_event_melanoma_count': ['new',
#   'tumor',
#   'event',
#   'melanoma',
#   'count'],
#  'new_tumor_event_melanoma_site': ['new',
#   'tumor',
#   'event',
#   'melanoma',
#   'site'],
#  'new_tumor_event_histo_type': ['new', 'tumor', 'event', 'histo', 'type'],
#  'clinical_status_within_3_mths_surgery': ['clinical',
#   'status',
#   'within',
#   '3',
#   'mths',
#   'surgery'],
#  'nte_er_positivity_scale_used': ['nte', 'er', 'positivity', 'scale', 'used'],
#  'nte_pr_positivity_scale_used': ['nte', 'pr', 'positivity', 'scale', 'used'],
#  'pharm_tx_mitotane_adjuvant': ['pharm', 'tx', 'mitotane', 'adjuvant'],
#  'pharm_tx_mitotane_theraputic_levels': ['pharm',
#   'tx',
#   'mitotane',
#   'theraputic',
#   'levels'],
#  'days_to_death': ['days', 'to', 'death'],
#  'days_to_last_followup': ['days', 'to', 'last', 'followup'],
#  'radiation_treatment_adjuvant.1': ['radiation', 'treatment', 'adjuvant.1'],
#  'pharmaceutical_tx_adjuvant.1': ['pharmaceutical', 'tx', 'adjuvant.1'],
#  'rt_tx_reason_not_completed.1': ['rt', 'tx', 'reason', 'not', 'completed.1'],
#  'rt_tx_reason_not_completed_other.1': ['rt',
#   'tx',
#   'reason',
#   'not',
#   'completed',
#   'other.1'],
#  'brachytherapy_type.1': ['brachytherapy', 'type.1'],
#  'brachytherapy_type_other.1': ['brachytherapy', 'type', 'other.1'],
#  'brachytherapy_total_dose_point_a.1': ['brachytherapy',
#   'total',
#   'dose',
#   'point',
#   'a.1'],
#  'radiation_therapy_xrt_type.1': ['radiation', 'therapy', 'xrt', 'type.1'],
#  'radiation_type_other.1': ['radiation', 'type', 'other.1'],
#  'rt_tx_total_dose_to_pelvis.1': ['rt',
#   'tx',
#   'total',
#   'dose',
#   'to',
#   'pelvis.1'],
#  'radiation_therapy_dose_paraaortic_nodes.1': ['radiation',
#   'therapy',
#   'dose',
#   'paraaortic',
#   'nodes.1'],
#  'radiation_concurrent_indicator': ['radiation', 'concurrent', 'indicator'],
#  'chemo_concurrent_reason_not_given.1': ['chemo',
#   'concurrent',
#   'reason',
#   'not',
#   'given.1'],
#  'chemo_concurrent_reason_not_other.1': ['chemo',
#   'concurrent',
#   'reason',
#   'not',
#   'other.1'],
#  'chemo_concurrent_type.1': ['chemo', 'concurrent', 'type.1'],
#  'chemo_concurrent_type_other.1': ['chemo', 'concurrent', 'type', 'other.1'],
#  'chemo_concurrent_dose.1': ['chemo', 'concurrent', 'dose.1'],
#  'chemo_concurrent_course.1': ['chemo', 'concurrent', 'course.1'],
#  'chemo_concurrent_fractions_total.1': ['chemo',
#   'concurrent',
#   'fractions',
#   'total.1'],
#  'prescribed_dose_units.1': ['prescribed', 'dose', 'units.1'],
#  'ablation_embolization_tx_adjuvant': ['ablation',
#   'embolization',
#   'tx',
#   'adjuvant'],
#  'days_to_new_tumor_event_after_initial_treatment': ['days',
#   'to',
#   'new',
#   'tumor',
#   'event',
#   'after',
#   'initial',
#   'treatment'],
#  'new_tumor_event_surgery.1': ['new', 'tumor', 'event', 'surgery.1'],
#  'new_tumor_event_liver_transplant': ['new',
#   'tumor',
#   'event',
#   'liver',
#   'transplant'],
#  'new_tumor_event_residual_tumor': ['new',
#   'tumor',
#   'event',
#   'residual',
#   'tumor'],
#  'new_tumor_event_ablation_embo_tx': ['new',
#   'tumor',
#   'event',
#   'ablation',
#   'embo',
#   'tx'],
#  'days_to_new_tumor_event_transplant': ['days',
#   'to',
#   'new',
#   'tumor',
#   'event',
#   'transplant'],
#  'additional_radiation_therapy': ['additional', 'radiation', 'therapy'],
#  'new_tumor_event_surgery_days_to.1': ['new',
#   'tumor',
#   'event',
#   'surgery',
#   'days',
#   'to.1'],
#  'nte_lesion_radiologic_length': ['nte', 'lesion', 'radiologic', 'length'],
#  'nte_lesion_radiologic_width': ['nte', 'lesion', 'radiologic', 'width'],
#  'nte_lesion_radiologic_depth': ['nte', 'lesion', 'radiologic', 'depth'],
#  'nte_lesion_pathologic_length': ['nte', 'lesion', 'pathologic', 'length'],
#  'nte_lesion_pathologic_width': ['nte', 'lesion', 'pathologic', 'width'],
#  'nte_lesion_pathologic_depth': ['nte', 'lesion', 'pathologic', 'depth'],
#  'nte_well_or_dedifferentiated_indicator': ['nte',
#   'well',
#   'or',
#   'dedifferentiated',
#   'indicator'],
#  'discontiguous_lesion_count': ['discontiguous', 'lesion', 'count'],
#  'pathologic_tumor_burden': ['pathologic', 'tumor', 'burden'],
#  'radiologic_tumor_burden': ['radiologic', 'tumor', 'burden'],
#  'tumor_multifocal': ['tumor', 'multifocal'],
#  'residual_tumor': ['residual', 'tumor'],
#  'new_neoplasm_histology_other': ['new', 'neoplasm', 'histology', 'other'],
#  'post_orchi_lymph_node_dissection': ['post',
#   'orchi',
#   'lymph',
#   'node',
#   'dissection'],
#  'molecular_test_result': ['molecular', 'test', 'result'],
#  'pet_scan_after_treatment_results': ['pet',
#   'scan',
#   'after',
#   'treatment',
#   'results'],
#  'death_cause_text': ['death', 'cause', 'text'],
#  'first_progression_biopsied_indicator': ['first',
#   'progression',
#   'biopsied',
#   'indicator'],
#  'lymphoma_progression_histology': ['lymphoma', 'progression', 'histology'],
#  'lymphoma_progression_histology_other': ['lymphoma',
#   'progression',
#   'histology',
#   'other'],
#  'tobacco_smokeless_use_at_dx': ['tobacco', 'smokeless', 'use', 'at', 'dx'],
#  'tobacco_smokeless_regular_use': ['tobacco', 'smokeless', 'regular', 'use'],
#  'tobacco_smokeless_average_per_day': ['tobacco',
#   'smokeless',
#   'average',
#   'per',
#   'day'],
#  'tobacco_smokeless_age_use_started': ['tobacco',
#   'smokeless',
#   'age',
#   'use',
#   'started'],
#  'tobacco_smokeless_age_use_ended': ['tobacco',
#   'smokeless',
#   'age',
#   'use',
#   'ended'],
#  'definitive_tx_method': ['definitive', 'tx', 'method'],
#  'definitive_tx_evidence_disease_after': ['definitive',
#   'tx',
#   'evidence',
#   'disease',
#   'after'],
#  'days_to_completion_of_curative_tx': ['days',
#   'to',
#   'completion',
#   'of',
#   'curative',
#   'tx'],
#  'disease_multifocal_indicator': ['disease', 'multifocal', 'indicator'],
#  'discontinuous_lesions_count': ['discontinuous', 'lesions', 'count'],
#  'tumor_burden_radiologic': ['tumor', 'burden', 'radiologic'],
#  'tumor_burden_pathologic': ['tumor', 'burden', 'pathologic'],
#  'residual_disease_post_new_tumor_event_margin_status.1': ['residual',
#   'disease',
#   'post',
#   'new',
#   'tumor',
#   'event',
#   'margin',
#   'status.1'],
#  'new_tumor_event_histology': ['new', 'tumor', 'event', 'histology'],
#  'bcr_omf_barcode': ['bcr', 'omf', 'barcode'],
#  'bcr_omf_uuid': ['bcr', 'omf', 'uuid'],
#  'malignancy_type': ['malignancy', 'type'],
#  'other_malignancy_dx_days_to': ['other', 'malignancy', 'dx', 'days', 'to'],
#  'surgery_indicator': ['surgery', 'indicator'],
#  'other_malignancy_surgery_type': ['other', 'malignancy', 'surgery', 'type'],
#  'other_malignancy_surgery_days_to': ['other',
#   'malignancy',
#   'surgery',
#   'days',
#   'to'],
#  'pharmaceutical_therapy_indicator': ['pharmaceutical',
#   'therapy',
#   'indicator'],
#  'pharmaceutical_therapy_extent': ['pharmaceutical', 'therapy', 'extent'],
#  'radiation_therapy_indicator': ['radiation', 'therapy', 'indicator'],
#  'radiation_therapy_extent': ['radiation', 'therapy', 'extent'],
#  'history_rt_tx_to_site_of_tcga_tumor': ['history',
#   'rt',
#   'tx',
#   'to',
#   'site',
#   'of',
#   'tcga',
#   'tumor'],
#  'radiation_therapy_started_days_to': ['radiation',
#   'therapy',
#   'started',
#   'days',
#   'to'],
#  'ajcc_staging_edition': ['ajcc', 'staging', 'edition'],
#  'ajcc_tumor_pathologic_pt': ['ajcc', 'tumor', 'pathologic', 'pt'],
#  'ajcc_nodes_pathologic_pn': ['ajcc', 'nodes', 'pathologic', 'pn'],
#  'ajcc_metastasis_pathologic_pm': ['ajcc', 'metastasis', 'pathologic', 'pm'],
#  'ajcc_pathologic_tumor_stage': ['ajcc', 'pathologic', 'tumor', 'stage'],
#  'clinical_stage': ['clinical', 'stage'],
#  'other_malignancy_anatomic_site': ['other', 'malignancy', 'anatomic', 'site'],
#  'other_malignancy_anatomic_site_text': ['other',
#   'malignancy',
#   'anatomic',
#   'site',
#   'text'],
#  'other_malignancy_histological_type': ['other',
#   'malignancy',
#   'histological',
#   'type'],
#  'other_malignancy_histological_type_text': ['other',
#   'malignancy',
#   'histological',
#   'type',
#   'text'],
#  'other_malignancy_laterality': ['other', 'malignancy', 'laterality'],
#  'stage_other': ['stage', 'other'],
#  'prospective_collection': ['prospective', 'collection'],
#  'retrospective_collection': ['retrospective', 'collection'],
#  'gender': ['gender'],
#  'race': ['race'],
#  'ethnicity': ['ethnicity'],
#  'history_other_malignancy': ['history', 'other', 'malignancy'],
#  'history_neoadjuvant_treatment': ['history', 'neoadjuvant', 'treatment'],
#  'pharm_tx_mitotane_indicator': ['pharm', 'tx', 'mitotane', 'indicator'],
#  'pharm_tx_mitotane_theraputic_at_rec': ['pharm',
#   'tx',
#   'mitotane',
#   'theraputic',
#   'at',
#   'rec'],
#  'pharm_tx_mitotane_for_macro_disease': ['pharm',
#   'tx',
#   'mitotane',
#   'for',
#   'macro',
#   'disease'],
#  'pharm_tx_mitotane_theraputic_macro': ['pharm',
#   'tx',
#   'mitotane',
#   'theraputic',
#   'macro'],
#  'pharm_tx_mitotane_theraputic_at_prog': ['pharm',
#   'tx',
#   'mitotane',
#   'theraputic',
#   'at',
#   'prog'],
#  'laterality': ['laterality'],
#  'histologic_diagnosis': ['histologic', 'diagnosis'],
#  'initial_pathologic_dx_year': ['initial', 'pathologic', 'dx', 'year'],
#  'ct_scan_preop_results': ['ct', 'scan', 'preop', 'results'],
#  'ct_scan_preop_results.1': ['ct', 'scan', 'preop', 'results.1'],
#  'lymph_nodes_examined': ['lymph', 'nodes', 'examined'],
#  'lymph_nodes_examined_count': ['lymph', 'nodes', 'examined', 'count'],
#  'lymph_nodes_examined_he_count': ['lymph',
#   'nodes',
#   'examined',
#   'he',
#   'count'],
#  'weiss_score_overall': ['weiss', 'score', 'overall'],
#  'mitoses_per_50_hpf': ['mitoses', 'per', '50', 'hpf'],
#  'metastatic_dx_confirmed_by': ['metastatic', 'dx', 'confirmed', 'by'],
#  'metastatic_dx_confirmed_by_other': ['metastatic',
#   'dx',
#   'confirmed',
#   'by',
#   'other'],
#  'metastatic_tumor_site': ['metastatic', 'tumor', 'site'],
#  'metastatic_tumor_site.1': ['metastatic', 'tumor', 'site.1'],
#  'history_adrenal_hormone_excess': ['history', 'adrenal', 'hormone', 'excess'],
#  'history_basis_adrenal_hormone_dx': ['history',
#   'basis',
#   'adrenal',
#   'hormone',
#   'dx'],
#  'molecular_studies_others_performed': ['molecular',
#   'studies',
#   'others',
#   'performed'],
#  'age_at_initial_pathologic_diagnosis': ['age',
#   'at',
#   'initial',
#   'pathologic',
#   'diagnosis'],
#  'atypical_mitotic_figures': ['atypical', 'mitotic', 'figures'],
#  'clinical_M': ['clinical', 'm'],
#  'clinical_N': ['clinical', 'n'],
#  'clinical_T': ['clinical', 't'],
#  'cytoplasm_presence_less_than_equal_25_percent': ['cytoplasm',
#   'presence',
#   'less',
#   'than',
#   'equal',
#   '25',
#   'percent'],
#  'days_to_birth': ['days', 'to', 'birth'],
#  'days_to_initial_pathologic_diagnosis': ['days',
#   'to',
#   'initial',
#   'pathologic',
#   'diagnosis'],
#  'diffuse_architecture': ['diffuse', 'architecture'],
#  'disease_code': ['disease', 'code'],
#  'extranodal_involvement': ['extranodal', 'involvement'],
#  'icd_10': ['icd', '10'],
#  'icd_o_3_histology': ['icd', 'o', '3', 'histology'],
#  'icd_o_3_site': ['icd', 'o', '3', 'site'],
#  'informed_consent_verified': ['informed', 'consent', 'verified'],
#  'invasion_of_tumor_capsule': ['invasion', 'of', 'tumor', 'capsule'],
#  'mitotic_rate': ['mitotic', 'rate'],
#  'necrosis': ['necrosis'],
#  'nuclear_grade_III_IV': ['nuclear', 'grade', 'iii', 'iv'],
#  'pathologic_M': ['pathologic', 'm'],
#  'pathologic_N': ['pathologic', 'n'],
#  'pathologic_T': ['pathologic', 't'],
#  'patient_id': ['patient', 'id'],
#  'project_code': ['project', 'code'],
#  'ret': ['ret'],
#  'sdha': ['sdha'],
#  'sdhaf2_sdh5': ['sdhaf2', 'sdh5'],
#  'sdhb': ['sdhb'],
#  'sdhc': ['sdhc'],
#  'sdhd': ['sdhd'],
#  'sinusoid_invasion': ['sinusoid', 'invasion'],
#  'system_version': ['system', 'version'],
#  'tissue_source_site': ['tissue', 'source', 'site'],
#  'tmem127': ['tmem127'],
#  'tumor_tissue_site': ['tumor', 'tissue', 'site'],
#  'vhl': ['vhl'],
#  'weiss_venous_invasion': ['weiss', 'venous', 'invasion'],
#  'birth_days_to': ['birth', 'days', 'to'],
#  'height_cm_at_diagnosis': ['height', 'cm', 'at', 'diagnosis'],
#  'weight_kg_at_diagnosis': ['weight', 'kg', 'at', 'diagnosis'],
#  'noninvasive_bladder_history': ['noninvasive', 'bladder', 'history'],
#  'noninvasive_bladder_ca_tx_type': ['noninvasive',
#   'bladder',
#   'ca',
#   'tx',
#   'type'],
#  'bcg_tx_90_days_prior_to_resection': ['bcg',
#   'tx',
#   '90',
#   'days',
#   'prior',
#   'to',
#   'resection'],
#  'bcg_tx_complete_response': ['bcg', 'tx', 'complete', 'response'],
#  'bcg_tx_induction_courses_indicator': ['bcg',
#   'tx',
#   'induction',
#   'courses',
#   'indicator'],
#  'bcg_tx_maintenance_courses_indicator': ['bcg',
#   'tx',
#   'maintenance',
#   'courses',
#   'indicator'],
#  'bcg_complete_response_months': ['bcg', 'complete', 'response', 'months'],
#  'occupation_current': ['occupation', 'current'],
#  'occupation_primary': ['occupation', 'primary'],
#  'occupation_primary_chemical_exposure': ['occupation',
#   'primary',
#   'chemical',
#   'exposure'],
#  'occupation_primary_industry': ['occupation', 'primary', 'industry'],
#  'occupation_primary_years_worked': ['occupation',
#   'primary',
#   'years',
#   'worked'],
#  'tobacco_smoking_history_indicator': ['tobacco',
#   'smoking',
#   'history',
#   'indicator'],
#  'tobacco_smoking_age_started': ['tobacco', 'smoking', 'age', 'started'],
#  'tobacco_smoking_year_stopped': ['tobacco', 'smoking', 'year', 'stopped'],
#  'tobacco_smoking_pack_years_smoked': ['tobacco',
#   'smoking',
#   'pack',
#   'years',
#   'smoked'],
#  'family_history_cancer_relationship': ['family',
#   'history',
#   'cancer',
#   'relationship'],
#  'family_history_cancer_type': ['family', 'history', 'cancer', 'type'],
#  'histologic_subtype': ['histologic', 'subtype'],
#  'age_at_diagnosis': ['age', 'at', 'diagnosis'],
#  'method_initial_path_dx': ['method', 'initial', 'path', 'dx'],
#  'method_initial_path_dx_other': ['method', 'initial', 'path', 'dx', 'other'],
#  'lymphovascular_invasion': ['lymphovascular', 'invasion'],
#  'extracapsular_extension': ['extracapsular', 'extension'],
#  'extracapsular_extension_present': ['extracapsular', 'extension', 'present'],
#  'metastasis_site': ['metastasis', 'site'],
#  'metastatic_site_other': ['metastatic', 'site', 'other'],
#  'incidental_prostate_cancer_indicator': ['incidental',
#   'prostate',
#   'cancer',
#   'indicator'],
#  'ajcc_path_pt_incidental_prostate': ['ajcc',
#   'path',
#   'pt',
#   'incidental',
#   'prostate'],
#  'anatomic_neoplasm_subdivision': ['anatomic', 'neoplasm', 'subdivision'],
#  'histological_type': ['histological', 'type'],
#  'neoplasm_histologic_grade': ['neoplasm', 'histologic', 'grade'],
#  'menopause_status': ['menopause', 'status'],
#  'histologic_diagnosis_other': ['histologic', 'diagnosis', 'other'],
#  'surgical_procedure_first': ['surgical', 'procedure', 'first'],
#  'first_surgical_procedure_other': ['first', 'surgical', 'procedure', 'other'],
#  'margin_status': ['margin', 'status'],
#  'surgery_for_positive_margins': ['surgery', 'for', 'positive', 'margins'],
#  'surgery_for_positive_margins_other': ['surgery',
#   'for',
#   'positive',
#   'margins',
#   'other'],
#  'margin_status_reexcision': ['margin', 'status', 'reexcision'],
#  'axillary_staging_method': ['axillary', 'staging', 'method'],
#  'axillary_staging_method_other': ['axillary', 'staging', 'method', 'other'],
#  'micromet_detection_by_ihc': ['micromet', 'detection', 'by', 'ihc'],
#  'lymph_nodes_examined_ihc_count': ['lymph',
#   'nodes',
#   'examined',
#   'ihc',
#   'count'],
#  'metastasis_site_other': ['metastasis', 'site', 'other'],
#  'er_positivity_scale_used': ['er', 'positivity', 'scale', 'used'],
#  'pr_positivity_scale_used': ['pr', 'positivity', 'scale', 'used'],
#  'days_to_patient_progression_free': ['days',
#   'to',
#   'patient',
#   'progression',
#   'free'],
#  'days_to_tumor_progression': ['days', 'to', 'tumor', 'progression'],
#  'metastatic_tumor_indicator': ['metastatic', 'tumor', 'indicator'],
#  'site_of_primary_tumor_other': ['site', 'of', 'primary', 'tumor', 'other'],
#  'family_history_cancer_indicator': ['family',
#   'history',
#   'cancer',
#   'indicator'],
#  'family_history_cancer_number_relatives': ['family',
#   'history',
#   'cancer',
#   'number',
#   'relatives'],
#  'family_cancer_type_txt': ['family', 'cancer', 'type', 'txt'],
#  'history_hepato_carcinoma_risk_factors': ['history',
#   'hepato',
#   'carcinoma',
#   'risk',
#   'factors'],
#  'other_hepato_carcinoma_risk_factors': ['other',
#   'hepato',
#   'carcinoma',
#   'risk',
#   'factors'],
#  'submitted_tumor_site': ['submitted', 'tumor', 'site'],
#  'definitive_surgical_procedure': ['definitive', 'surgical', 'procedure'],
#  'tumor_grade': ['tumor', 'grade'],
#  'vascular_invasion': ['vascular', 'invasion'],
#  'perineural_invasion': ['perineural', 'invasion'],
#  'child_pugh_classification': ['child', 'pugh', 'classification'],
#  'ca_19_9_level': ['ca', '19', '9', 'level'],
#  'ca_19_9_level_lower': ['ca', '19', '9', 'level', 'lower'],
#  'ca_19_9_level_upper': ['ca', '19', '9', 'level', 'upper'],
#  'alpha_fetoprotien_at_procurement': ['alpha',
#   'fetoprotien',
#   'at',
#   'procurement'],
#  'alpha_fetoprotien_norm_range_lower': ['alpha',
#   'fetoprotien',
#   'norm',
#   'range',
#   'lower'],
#  'alpha_fetoprotien_norm_range_upper': ['alpha',
#   'fetoprotien',
#   'norm',
#   'range',
#   'upper'],
#  'platelet_count_preresection': ['platelet', 'count', 'preresection'],
#  'platelet_norm_range_lower': ['platelet', 'norm', 'range', 'lower'],
#  'platelet_norm_range_upper': ['platelet', 'norm', 'range', 'upper'],
#  'prothrombin_time_INR_at_procurement': ['prothrombin',
#   'time',
#   'inr',
#   'at',
#   'procurement'],
#  'prothrom_time_INR_norm_range_lower': ['prothrom',
#   'time',
#   'inr',
#   'norm',
#   'range',
#   'lower'],
#  'prothrombin_time_norm_range_upper': ['prothrombin',
#   'time',
#   'norm',
#   'range',
#   'upper'],
#  'serum_albumin_preresection': ['serum', 'albumin', 'preresection'],
#  'serum_albumin_norm_range_lower': ['serum',
#   'albumin',
#   'norm',
#   'range',
#   'lower'],
#  'serum_albumin_norm_range_upper': ['serum',
#   'albumin',
#   'norm',
#   'range',
#   'upper'],
#  'bilirubin_total': ['bilirubin', 'total'],
#  'bilirubin_total_norm_range_lower': ['bilirubin',
#   'total',
#   'norm',
#   'range',
#   'lower'],
#  'bilirubin_total_norm_range_upper': ['bilirubin',
#   'total',
#   'norm',
#   'range',
#   'upper'],
#  'creatinine_level_preresection': ['creatinine', 'level', 'preresection'],
#  'creatinine_norm_range_lower': ['creatinine', 'norm', 'range', 'lower'],
#  'creatinine_norm_range_upper': ['creatinine', 'norm', 'range', 'upper'],
#  'ishak_fibrosis_score': ['ishak', 'fibrosis', 'score'],
#  'cholangitis_tissue_evidence': ['cholangitis', 'tissue', 'evidence'],
#  'year_of_initial_pathologic_diagnosis': ['year',
#   'of',
#   'initial',
#   'pathologic',
#   'diagnosis'],
#  'cea_level_pretreatment': ['cea', 'level', 'pretreatment'],
#  'specimen_non_node_tumor_deposits': ['specimen',
#   'non',
#   'node',
#   'tumor',
#   'deposits'],
#  'circumferential_resection_margin_crm': ['circumferential',
#   'resection',
#   'margin',
#   'crm'],
#  'vascular_invasion_indicator': ['vascular', 'invasion', 'indicator'],
#  'lymphovascular_invasion_indicator': ['lymphovascular',
#   'invasion',
#   'indicator'],
#  'microsatellite_instability': ['microsatellite', 'instability'],
#  'loci_tested_count': ['loci', 'tested', 'count'],
#  'loci_abnormal_count': ['loci', 'abnormal', 'count'],
#  'mismatch_rep_proteins_tested_by_ihc': ['mismatch',
#   'rep',
#   'proteins',
#   'tested',
#   'by',
#   'ihc'],
#  'mismatch_rep_proteins_loss_ihc': ['mismatch',
#   'rep',
#   'proteins',
#   'loss',
#   'ihc'],
#  'kras_gene_analysis_indicator': ['kras', 'gene', 'analysis', 'indicator'],
#  'kras_mutation_found': ['kras', 'mutation', 'found'],
#  'kras_mutation_codon': ['kras', 'mutation', 'codon'],
#  'braf_gene_analysis_indicator': ['braf', 'gene', 'analysis', 'indicator'],
#  'braf_gene_analysis_result': ['braf', 'gene', 'analysis', 'result'],
#  'history_other_malignancy.1': ['history', 'other', 'malignancy.1'],
#  'history_colon_polyps': ['history', 'colon', 'polyps'],
#  'colon_polyps_at_procurement_indicator': ['colon',
#   'polyps',
#   'at',
#   'procurement',
#   'indicator'],
#  'family_history_colorectal_cancer': ['family',
#   'history',
#   'colorectal',
#   'cancer'],
#  'eastern_cancer_oncology_group': ['eastern', 'cancer', 'oncology', 'group'],
#  'initial_pathologic_diagnosis_method': ['initial',
#   'pathologic',
#   'diagnosis',
#   'method'],
#  'karnofsky_performance_score': ['karnofsky', 'performance', 'score'],
#  'number_pack_years_smoked': ['number', 'pack', 'years', 'smoked'],
#  'stopped_smoking_year': ['stopped', 'smoking', 'year'],
#  'tobacco_smoking_history': ['tobacco', 'smoking', 'history'],
#  'year_of_tobacco_smoking_onset': ['year',
#   'of',
#   'tobacco',
#   'smoking',
#   'onset'],
#  'birth_country': ['birth', 'country'],
#  'tumor_sample_procurement_country': ['tumor',
#   'sample',
#   'procurement',
#   'country'],
#  'cancer_procurement_state_province': ['cancer',
#   'procurement',
#   'state',
#   'province'],
#  'cancer_procurement_city': ['cancer', 'procurement', 'city'],
#  'alcohol_consumption_frequency': ['alcohol', 'consumption', 'frequency'],
#  'alcohol_consumption_per_day': ['alcohol', 'consumption', 'per', 'day'],
#  'history_reflux_disease_indicator': ['history',
#   'reflux',
#   'disease',
#   'indicator'],
#  'history_reflux_disease_treatment': ['history',
#   'reflux',
#   'disease',
#   'treatment'],
#  'history_hpylori_infection_indicator': ['history',
#   'hpylori',
#   'infection',
#   'indicator'],
#  'initial_diagnosis_esophageal_ca_type': ['initial',
#   'diagnosis',
#   'esophageal',
#   'ca',
#   'type'],
#  'history_barretts_esophageal_indicator': ['history',
#   'barretts',
#   'esophageal',
#   'indicator'],
#  'history_if_barretts_goblet_cell_indicator': ['history',
#   'if',
#   'barretts',
#   'goblet',
#   'cell',
#   'indicator'],
#  'family_history_esoph_gastic_cancer': ['family',
#   'history',
#   'esoph',
#   'gastic',
#   'cancer'],
#  'number_of_relatives_diagnosed': ['number', 'of', 'relatives', 'diagnosed'],
#  'esophageal_tumor_location_centered': ['esophageal',
#   'tumor',
#   'location',
#   'centered'],
#  'esophageal_tumor_location_involved': ['esophageal',
#   'tumor',
#   'location',
#   'involved'],
#  'esoph_columnar_metaplasia_indicator': ['esoph',
#   'columnar',
#   'metaplasia',
#   'indicator'],
#  'columnar_metaplasia_goblet_cell_indicator': ['columnar',
#   'metaplasia',
#   'goblet',
#   'cell',
#   'indicator'],
#  'esoph_non_ca_degree_of_dysplasia': ['esoph',
#   'non',
#   'ca',
#   'degree',
#   'of',
#   'dysplasia'],
#  'lymph_node_sprd_radiograph_evidence': ['lymph',
#   'node',
#   'sprd',
#   'radiograph',
#   'evidence'],
#  'ajcc_tumor_clinical_ct': ['ajcc', 'tumor', 'clinical', 'ct'],
#  'ajcc_nodes_clinical_cn': ['ajcc', 'nodes', 'clinical', 'cn'],
#  'ajcc_metastasis_clinical_cm': ['ajcc', 'metastasis', 'clinical', 'cm'],
#  'ajcc_clinical_tumor_stage': ['ajcc', 'clinical', 'tumor', 'stage'],
#  'patient_to_undergo_surgery': ['patient', 'to', 'undergo', 'surgery'],
#  'treatment_prior_to_surgery_indicator': ['treatment',
#   'prior',
#   'to',
#   'surgery',
#   'indicator'],
#  'alcohol_history_documented': ['alcohol', 'history', 'documented'],
#  'history_lgg_dx_of_brain_tissue': ['history',
#   'lgg',
#   'dx',
#   'of',
#   'brain',
#   'tissue'],
#  'anatomic_organ_subdivision': ['anatomic', 'organ', 'subdivision'],
#  'lymph_node_neck_dissection_indicator': ['lymph',
#   'node',
#   'neck',
#   'dissection',
#   'indicator'],
#  'lymph_node_dissection_method': ['lymph', 'node', 'dissection', 'method'],
#  'lymph_node_dissection_method.1': ['lymph', 'node', 'dissection', 'method.1'],
#  'p53_gene_analysis': ['p53', 'gene', 'analysis'],
#  'egfr_amplification_status': ['egfr', 'amplification', 'status'],
#  'extracapsular_spread_pathologic': ['extracapsular', 'spread', 'pathologic'],
#  'hpv_status_p16': ['hpv', 'status', 'p16'],
#  'hpv_status_ish': ['hpv', 'status', 'ish'],
#  'tobacco_smoking_year_started': ['tobacco', 'smoking', 'year', 'started'],
#  'sarcomatoid_features': ['sarcomatoid', 'features'],
#  'sarcomatoid_percent_of_tumor': ['sarcomatoid', 'percent', 'of', 'tumor'],
#  'lymph_nodes_examined_positive': ['lymph', 'nodes', 'examined', 'positive'],
#  'ldh_level': ['ldh', 'level'],
#  'serum_calcium_level': ['serum', 'calcium', 'level'],
#  'hemoglobin_level': ['hemoglobin', 'level'],
#  'platelet_count': ['platelet', 'count'],
#  'white_cell_count': ['white', 'cell', 'count'],
#  'erythrocyte_sedimentation_rate': ['erythrocyte', 'sedimentation', 'rate'],
#  'tumor_type': ['tumor', 'type'],
#  'viral_hepatitis_serology': ['viral', 'hepatitis', 'serology'],
#  'hepatic_inflammation_adj_tissue': ['hepatic',
#   'inflammation',
#   'adj',
#   'tissue'],
#  'location_lung_parenchyma': ['location', 'lung', 'parenchyma'],
#  'histologic_diagnosis.1': ['histologic', 'diagnosis.1'],
#  'pulmonary_function_test_indicator': ['pulmonary',
#   'function',
#   'test',
#   'indicator'],
#  'fev1_percent_ref_prebroncholiator': ['fev1',
#   'percent',
#   'ref',
#   'prebroncholiator'],
#  'fev1_percent_ref_postbroncholiator': ['fev1',
#   'percent',
#   'ref',
#   'postbroncholiator'],
#  'fev1_fvc_ratio_prebroncholiator': ['fev1',
#   'fvc',
#   'ratio',
#   'prebroncholiator'],
#  'fev1_fvc_ratio_postbroncholiator': ['fev1',
#   'fvc',
#   'ratio',
#   'postbroncholiator'],
#  'carbon_monoxide_diffusion_dlco': ['carbon', 'monoxide', 'diffusion', 'dlco'],
#  'kras_mutation_identified_type': ['kras', 'mutation', 'identified', 'type'],
#  'egfr_mutation_status': ['egfr', 'mutation', 'status'],
#  'egfr_mutation_identified_type': ['egfr', 'mutation', 'identified', 'type'],
#  'eml4_alk_translocation_status': ['eml4', 'alk', 'translocation', 'status'],
#  'eml4_alk_analysis_type': ['eml4', 'alk', 'analysis', 'type'],
#  'age_began_smoking_in_years': ['age', 'began', 'smoking', 'in', 'years'],
#  'anatomic_neoplasm_subdivision_other': ['anatomic',
#   'neoplasm',
#   'subdivision',
#   'other'],
#  'cd4_counts_at_diagnosis': ['cd4', 'counts', 'at', 'diagnosis'],
#  'cdc_hiv_risk_group': ['cdc', 'hiv', 'risk', 'group'],
#  'days_to_hiv_diagnosis': ['days', 'to', 'hiv', 'diagnosis'],
#  'days_to_sample_procurement': ['days', 'to', 'sample', 'procurement'],
#  'egfr_mutation_identified': ['egfr', 'mutation', 'identified'],
#  'eml4_alk_translocation_identified': ['eml4',
#   'alk',
#   'translocation',
#   'identified'],
#  'eml4_alk_translocation_variant': ['eml4', 'alk', 'translocation', 'variant'],
#  'hbv_test': ['hbv', 'test'],
#  'hcv_test': ['hcv', 'test'],
#  'height': ['height'],
#  'history_immunological_disease': ['history', 'immunological', 'disease'],
#  'history_immunological_disease_other': ['history',
#   'immunological',
#   'disease',
#   'other'],
#  'history_immunosuppresive_rx': ['history', 'immunosuppresive', 'rx'],
#  'history_immunosuppressive_rx_other': ['history',
#   'immunosuppressive',
#   'rx',
#   'other'],
#  'history_of_other_malignancy': ['history', 'of', 'other', 'malignancy'],
#  'history_relevant_infectious_dx': ['history', 'relevant', 'infectious', 'dx'],
#  'history_relevant_infectious_dx_other': ['history',
#   'relevant',
#   'infectious',
#   'dx',
#   'other'],
#  'hiv_rna_load_at_diagnosis': ['hiv', 'rna', 'load', 'at', 'diagnosis'],
#  'hiv_status': ['hiv', 'status'],
#  'hpv_test': ['hpv', 'test'],
#  'kshv_hhv8_test': ['kshv', 'hhv8', 'test'],
#  'lost_follow_up': ['lost', 'follow', 'up'],
#  'lymph_node_examined_count': ['lymph', 'node', 'examined', 'count'],
#  'nadir_cd4_counts': ['nadir', 'cd4', 'counts'],
#  'number_of_lymphnodes_positive_by_he': ['number',
#   'of',
#   'lymphnodes',
#   'positive',
#   'by',
#   'he'],
#  'number_of_lymphnodes_positive_by_ihc': ['number',
#   'of',
#   'lymphnodes',
#   'positive',
#   'by',
#   'ihc'],
#  'on_haart_therapy_at_cancer_diagnosis': ['on',
#   'haart',
#   'therapy',
#   'at',
#   'cancer',
#   'diagnosis'],
#  'on_haart_therapy_prior_to_cancer_diagnosis': ['on',
#   'haart',
#   'therapy',
#   'prior',
#   'to',
#   'cancer',
#   'diagnosis'],
#  'pos_lymph_node_location': ['pos', 'lymph', 'node', 'location'],
#  'pos_lymph_node_location_other': ['pos',
#   'lymph',
#   'node',
#   'location',
#   'other'],
#  'primary_lymph_node_presentation_assessment': ['primary',
#   'lymph',
#   'node',
#   'presentation',
#   'assessment'],
#  'prior_aids_conditions': ['prior', 'aids', 'conditions'],
#  'weight': ['weight'],
#  'pleurodesis_performed_prior': ['pleurodesis', 'performed', 'prior'],
#  'pleurodesis_performed_90_days': ['pleurodesis', 'performed', '90', 'days'],
#  'history_asbestos_exposure': ['history', 'asbestos', 'exposure'],
#  'asbestos_exposure_type': ['asbestos', 'exposure', 'type'],
#  'asbestos_exposure_source': ['asbestos', 'exposure', 'source'],
#  'asbestos_exposure_age_first': ['asbestos', 'exposure', 'age', 'first'],
#  'asbestos_exposure_years': ['asbestos', 'exposure', 'years'],
#  'asbestos_exposure_age_last': ['asbestos', 'exposure', 'age', 'last'],
#  'primary_occupation': ['primary', 'occupation'],
#  'serum_mesothelin_prior_tx': ['serum', 'mesothelin', 'prior', 'tx'],
#  'serum_mesothelin_lower_limit': ['serum', 'mesothelin', 'lower', 'limit'],
#  'serum_mesothelin_upper_limit': ['serum', 'mesothelin', 'upper', 'limit'],
#  'creatinine_prior_tx': ['creatinine', 'prior', 'tx'],
#  'suv_of_pleura_max': ['suv', 'of', 'pleura', 'max'],
#  'mesothelioma_detection_method': ['mesothelioma', 'detection', 'method'],
#  'family_history_cancer_type_other': ['family',
#   'history',
#   'cancer',
#   'type',
#   'other'],
#  'jewish_religion_heritage_indicator': ['jewish',
#   'religion',
#   'heritage',
#   'indicator'],
#  'residual_disease_largest_nodule': ['residual',
#   'disease',
#   'largest',
#   'nodule'],
#  'pathologic_stage': ['pathologic', 'stage'],
#  'invasive_adenocarcinoma_indicator': ['invasive',
#   'adenocarcinoma',
#   'indicator'],
#  'tumor_sample_type': ['tumor', 'sample', 'type'],
#  'surgical_procedure': ['surgical', 'procedure'],
#  'grade_tier_system': ['grade', 'tier', 'system'],
#  'tumor_resected_max_dimension': ['tumor', 'resected', 'max', 'dimension'],
#  'alcohol_exposure_intensity': ['alcohol', 'exposure', 'intensity'],
#  'diabetes_diagnosis_days_to': ['diabetes', 'diagnosis', 'days', 'to'],
#  'history_chronic_pancreatitis': ['history', 'chronic', 'pancreatitis'],
#  'history_chronic_pancreatitis_days_to': ['history',
#   'chronic',
#   'pancreatitis',
#   'days',
#   'to'],
#  'history_pheo_or_para_include_benign': ['history',
#   'pheo',
#   'or',
#   'para',
#   'include',
#   'benign'],
#  'history_pheo_or_para_anatomic_site': ['history',
#   'pheo',
#   'or',
#   'para',
#   'anatomic',
#   'site'],
#  'related_tumors_outside_adrenal_glands': ['related',
#   'tumors',
#   'outside',
#   'adrenal',
#   'glands'],
#  'disease_detected_on_screening': ['disease', 'detected', 'on', 'screening'],
#  'zone_of_origin': ['zone', 'of', 'origin'],
#  'gleason_pattern_primary': ['gleason', 'pattern', 'primary'],
#  'gleason_pattern_secondary': ['gleason', 'pattern', 'secondary'],
#  'gleason_score': ['gleason', 'score'],
#  'gleason_pattern_tertiary': ['gleason', 'pattern', 'tertiary'],
#  'tumor_level': ['tumor', 'level'],
#  'days_to_bone_scan': ['days', 'to', 'bone', 'scan'],
#  'bone_scan_results': ['bone', 'scan', 'results'],
#  'ct_scan_ab_pelvis_indicator': ['ct', 'scan', 'ab', 'pelvis', 'indicator'],
#  'days_to_ct_scan_ab_pelvis': ['days', 'to', 'ct', 'scan', 'ab', 'pelvis'],
#  'ct_scan_ab_pelvis_results': ['ct', 'scan', 'ab', 'pelvis', 'results'],
#  'mri_at_diagnosis': ['mri', 'at', 'diagnosis'],
#  'days_to_mri': ['days', 'to', 'mri'],
#  'mri_results': ['mri', 'results'],
#  'days_to_psa_most_recent': ['days', 'to', 'psa', 'most', 'recent'],
#  'psa_most_recent_results': ['psa', 'most', 'recent', 'results'],
#  'biochemical_recurrence_indicator': ['biochemical',
#   'recurrence',
#   'indicator'],
#  'leiomyosarcoma_uterine_involvement': ['leiomyosarcoma',
#   'uterine',
#   'involvement'],
#  'leiomyo_major_vessel_involvement': ['leiomyo',
#   'major',
#   'vessel',
#   'involvement'],
#  'synovial_ss18ssx_fusion_status': ['synovial', 'ss18ssx', 'fusion', 'status'],
#  'synovial_ss18ssx_testing_method': ['synovial',
#   'ss18ssx',
#   'testing',
#   'method'],
#  'mpnst_nf_indicator': ['mpnst', 'nf', 'indicator'],
#  'mpnst_nf_familial_or_sporadic': ['mpnst',
#   'nf',
#   'familial',
#   'or',
#   'sporadic'],
#  'mpnst_plexiform_neurofibroma_site': ['mpnst',
#   'plexiform',
#   'neurofibroma',
#   'site'],
#  'mpnst_nf1_genetic_testing_indicator': ['mpnst',
#   'nf1',
#   'genetic',
#   'testing',
#   'indicator'],
#  'mpnst_nf1_mutations_identified': ['mpnst', 'nf1', 'mutations', 'identified'],
#  'tumor_total_depth': ['tumor', 'total', 'depth'],
#  'tumor_total_necrosis': ['tumor', 'total', 'necrosis'],
#  'necrosis_percent': ['necrosis', 'percent'],
#  'mitotic_count': ['mitotic', 'count'],
#  'locoregional_recurrence_indicator': ['locoregional',
#   'recurrence',
#   'indicator'],
#  'metastatic_disease_confirmed': ['metastatic', 'disease', 'confirmed'],
#  'contiguous_organ_resection': ['contiguous', 'organ', 'resection'],
#  'contiguous_organ_resection_other': ['contiguous',
#   'organ',
#   'resection',
#   'other'],
#  'contiguous_organ_invaded': ['contiguous', 'organ', 'invaded'],
#  'well_diff_liposarc_prior_dx_indicator': ['well',
#   'diff',
#   'liposarc',
#   'prior',
#   'dx',
#   'indicator'],
#  'well_diff_liposarc_prior_dx_days_to': ['well',
#   'diff',
#   'liposarc',
#   'prior',
#   'dx',
#   'days',
#   'to'],
#  'well_diff_liposarc_resection_days_to': ['well',
#   'diff',
#   'liposarc',
#   'resection',
#   'days',
#   'to'],
#  'primary_melanoma_known_dx': ['primary', 'melanoma', 'known', 'dx'],
#  'primary_multiple_at_dx': ['primary', 'multiple', 'at', 'dx'],
#  'primary_at_dx_count': ['primary', 'at', 'dx', 'count'],
#  'breslow_thickness_at_diagnosis': ['breslow', 'thickness', 'at', 'diagnosis'],
#  'clark_level_at_diagnosis': ['clark', 'level', 'at', 'diagnosis'],
#  'primary_melanoma_tumor_ulceration': ['primary',
#   'melanoma',
#   'tumor',
#   'ulceration'],
#  'primary_melanoma_mitotic_rate': ['primary', 'melanoma', 'mitotic', 'rate'],
#  'submitted_tumor_dx_days_to': ['submitted', 'tumor', 'dx', 'days', 'to'],
#  'submitted_tumor_site.1': ['submitted', 'tumor', 'site.1'],
#  'primary_melanoma_skin_type': ['primary', 'melanoma', 'skin', 'type'],
#  'history_neoadjuvant_tx_type': ['history', 'neoadjuvant', 'tx', 'type'],
#  'ifn_tx_90_days_prior_to_resection': ['ifn',
#   'tx',
#   '90',
#   'days',
#   'prior',
#   'to',
#   'resection'],
#  'new_tumor_event_prior_to_bcr_tumor': ['new',
#   'tumor',
#   'event',
#   'prior',
#   'to',
#   'bcr',
#   'tumor'],
#  'tumor_tissue_site_other': ['tumor', 'tissue', 'site', 'other'],
#  'antireflux_treatment': ['antireflux', 'treatment'],
#  'family_history_of_stomach_cancer': ['family',
#   'history',
#   'of',
#   'stomach',
#   'cancer'],
#  'number_of_relatives_with_stomach_cancer': ['number',
#   'of',
#   'relatives',
#   'with',
#   'stomach',
#   'cancer'],
#  'antireflux_treatment_type': ['antireflux', 'treatment', 'type'],
#  'barretts_esophagus': ['barretts', 'esophagus'],
#  'h_pylori_infection': ['h', 'pylori', 'infection'],
#  'history_thyroid_disease': ['history', 'thyroid', 'disease'],
#  'history_thyroid_disease_other': ['history', 'thyroid', 'disease', 'other'],
#  'family_history_thyroid_cancer': ['family', 'history', 'thyroid', 'cancer'],
#  'history_radiation_exposure': ['history', 'radiation', 'exposure'],
#  'tumor_focality': ['tumor', 'focality'],
#  'tumor_size_width': ['tumor', 'size', 'width'],
#  'tumor_size_width.1': ['tumor', 'size', 'width.1'],
#  'tumor_size_width.2': ['tumor', 'size', 'width.2'],
#  'lymph_nodes_preop_imaging': ['lymph', 'nodes', 'preop', 'imaging'],
#  'lymph_nodes_preop_imaging_type': ['lymph',
#   'nodes',
#   'preop',
#   'imaging',
#   'type'],
#  'extrathyroidal_extension': ['extrathyroidal', 'extension'],
#  'genotypic_analysis_detected': ['genotypic', 'analysis', 'detected'],
#  'braf_mutation_result': ['braf', 'mutation', 'result'],
#  'ras_mutation_result': ['ras', 'mutation', 'result'],
#  'ret_ptc_rearrangement_result': ['ret', 'ptc', 'rearrangement', 'result'],
#  'genotypic_analysis_results_other': ['genotypic',
#   'analysis',
#   'results',
#   'other'],
#  'genotyping_results_gene_mutation_not_reported_reason': ['genotyping',
#   'results',
#   'gene',
#   'mutation',
#   'not',
#   'reported',
#   'reason'],
#  'metastatic_site': ['metastatic', 'site'],
#  'other_metastatic_site': ['other', 'metastatic', 'site'],
#  'masaoka_stage': ['masaoka', 'stage'],
#  'history_myasthenia_gravis': ['history', 'myasthenia', 'gravis'],
#  'section_myasthenia_gravis': ['section', 'myasthenia', 'gravis'],
#  'surgical_approach_at_diagnosis': ['surgical', 'approach', 'at', 'diagnosis'],
#  'peritoneal_washing': ['peritoneal', 'washing'],
#  'tumor_invasion_percent': ['tumor', 'invasion', 'percent'],
#  'lymph_nodes_pelvic_examined_count': ['lymph',
#   'nodes',
#   'pelvic',
#   'examined',
#   'count'],
#  'lymph_nodes_pelvic_pos__by_he': ['lymph',
#   'nodes',
#   'pelvic',
#   'pos',
#   'by',
#   'he'],
#  'lymph_nodes_pelvic_pos_by_ihc': ['lymph',
#   'nodes',
#   'pelvic',
#   'pos',
#   'by',
#   'ihc'],
#  'lymph_nodes_pelvic_pos_total': ['lymph', 'nodes', 'pelvic', 'pos', 'total'],
#  'lymph_nodes_aortic_examined_count': ['lymph',
#   'nodes',
#   'aortic',
#   'examined',
#   'count'],
#  'lymph_nodes_aortic_pos_by_he': ['lymph',
#   'nodes',
#   'aortic',
#   'pos',
#   'by',
#   'he'],
#  'lymph_nodes_aortic_pos_by_ihc': ['lymph',
#   'nodes',
#   'aortic',
#   'pos',
#   'by',
#   'ihc'],
#  'lymph_nodes_aortic_pos_total': ['lymph', 'nodes', 'aortic', 'pos', 'total'],
#  'eye_color': ['eye', 'color'],
#  'tumor_morphology_percentage': ['tumor', 'morphology', 'percentage'],
#  'cytogenetic_abnormality_type': ['cytogenetic', 'abnormality', 'type'],
#  'gene_expression_profile': ['gene', 'expression', 'profile'],
#  'pet_ct_standardized_values': ['pet', 'ct', 'standardized', 'values'],
#  'extravascular_matrix_patterns': ['extravascular', 'matrix', 'patterns'],
#  'microvascular_density_mvd': ['microvascular', 'density', 'mvd'],
#  'tumor_infiltrating_lymphocytes': ['tumor', 'infiltrating', 'lymphocytes'],
#  'tumor_infiltrating_macrophages': ['tumor', 'infiltrating', 'macrophages'],
#  'tumor_basal_diameter': ['tumor', 'basal', 'diameter'],
#  'tumor_basal_diameter_mx': ['tumor', 'basal', 'diameter', 'mx'],
#  'tumor_thickness': ['tumor', 'thickness'],
#  'tumor_thickness_measurement': ['tumor', 'thickness', 'measurement'],
#  'extrascleral_extension': ['extrascleral', 'extension'],
#  'extranocular_nodule_size': ['extranocular', 'nodule', 'size'],
#  'tumor_shape_pathologic_clinical': ['tumor',
#   'shape',
#   'pathologic',
#   'clinical'],
#  'bcr_radiation_barcode': ['bcr', 'radiation', 'barcode'],
#  'bcr_radiation_uuid': ['bcr', 'radiation', 'uuid'],
#  'radiation_therapy_type': ['radiation', 'therapy', 'type'],
#  'radiation_therapy_site': ['radiation', 'therapy', 'site'],
#  'radiation_total_dose': ['radiation', 'total', 'dose'],
#  'radiation_adjuvant_units': ['radiation', 'adjuvant', 'units'],
#  'radiation_adjuvant_fractions_total': ['radiation',
#   'adjuvant',
#   'fractions',
#   'total'],
#  'radiation_therapy_ongoing_indicator': ['radiation',
#   'therapy',
#   'ongoing',
#   'indicator'],
#  'radiation_therapy_ended_days_to': ['radiation',
#   'therapy',
#   'ended',
#   'days',
#   'to'],
#  'course_number': ['course', 'number'],
#  'radiation_type_notes': ['radiation', 'type', 'notes']}

# %% [markdown]
# ## Create base table for unsupervised learning
#
# To create base tables I performed vectorized the long_names and permissible values of each CDE elements

# %%
abt = cde_data_modellers.create_base_for_unsupervised_learning()

# %%
abt.head()
# Out:
#            feature_vec_0_desc  feature_vec_1_desc  feature_vec_2_desc  \
# public_id
# 4122391              0.018435            0.047219           -0.009609
# 3108478              0.137383           -0.036843           -0.003032
# 3151106             -0.071497            0.011147            0.068213
# 3151541             -0.045924            0.026623           -0.024805
# 3108474             -0.078430            0.059689           -0.029348
#
#            feature_vec_3_desc  feature_vec_4_desc  feature_vec_5_desc  \
# public_id
# 4122391             -0.078648           -0.021142            0.060919
# 3108478             -0.074096            0.088070            0.179269
# 3151106             -0.004621           -0.101847           -0.074312
# 3151541             -0.114665           -0.030758           -0.021068
# 3108474             -0.056763           -0.018804            0.023530
#
#            feature_vec_6_desc  feature_vec_7_desc  feature_vec_8_desc  \
# public_id
# 4122391             -0.085244           -0.100023            0.086315
# 3108478             -0.133360           -0.056173            0.145608
# 3151106             -0.028229           -0.070336            0.035764
# 3151541              0.012422           -0.056003            0.042402
# 3108474             -0.099268           -0.165444            0.012464
#
#            feature_vec_9_desc  ...  feature_vec_42_val  feature_vec_43_val  \
# public_id                      ...
# 4122391             -0.080628  ...            0.007399           -0.062233
# 3108478              0.023625  ...            0.010528           -0.007853
# 3151106              0.015450  ...            0.000000            0.000000
# 3151541             -0.059203  ...           -0.030828           -0.107784
# 3108474              0.036713  ...           -0.073766            0.017912
#
#            feature_vec_44_val  feature_vec_45_val  feature_vec_46_val  \
# public_id
# 4122391              0.104100           -0.001613            0.033029
# 3108478             -0.001610           -0.004319           -0.094545
# 3151106              0.000000            0.000000            0.000000
# 3151541              0.094876            0.044965           -0.032447
# 3108474             -0.064114           -0.055719            0.111123
#
#            feature_vec_47_val  feature_vec_48_val  feature_vec_49_val  \
# public_id
# 4122391             -0.062997           -0.029849           -0.045373
# 3108478              0.027328           -0.140063           -0.261756
# 3151106              0.000000            0.000000            0.000000
# 3151541             -0.090023           -0.092303           -0.016453
# 3108474             -0.136497            0.074587           -0.004487
#
#            data_type_number  data_type_string
# public_id
# 4122391                   0                 1
# 3108478                   0                 1
# 3151106                   1                 0
# 3151541                   0                 1
# 3108474                   0                 1
#
# [5 rows x 102 columns]

# %% [markdown]
# ## Train an un-supervised machine learning model using the abt created above
# I created a wrapper class called create_model where a number of supervised and unsupervised learning algorithms are implemented (from sklearn library). The type and parameters of the model can be passed to this calss using the params dictionary.
#
# !!! Warning: Currently the the two datatype columns in the abt (data_type_string, data_type_number) are complementary and hence redundant. Only one should be used for modelling. This needs to be corrected in the future versions.

# %%
# import the Model class
from cde_modelling.modelling.create_models import Model

# create model
model = Model(params)

#fit the model
model.fit(abt)

# %% [markdown]
# ## Predict CDE elements for the clinical parameters
#
# Step1: Create an abt from the tcga dataset. This is done by vectorizing the headers (cinical parameters) and values, and dummy-fying the data_types. Then merging these vectors side by side, to create a design matrix (dataset). For this, I have created a method 'create_base_for_unsupervised_learning' in the CDE_data_modeller class. Note that the class has another method called 'create_abt', which creates base table for supervised learning. Each row in the former case represents a header (clinical parameter), where the later case represents a tuple (header, cde_element). Therefore,  the base table in the unsupervised case has the same number of rows as the the number of headers (or clinical parameters) in the dataset. But in case of the base table in the supervised case, the number of rows = the number of CDE elemtns times the number of headers (when no undersampling is performed.) <br><br>
#
# Step 2: Make predictions using the trained model
#
# Note that I have created a model.predict_and_convert_to_json function which returns the prediction in the following format: <br>
# {
# clinical parameter1: [most likely predictions, 2nd most likely prediction, .... , 20th most likely prediction] <br>
# clinical parameter2: [most likely predictions, 2nd most likely prediction, .... , 20th most likely prediction] <br>
# .....
# clinical parametern: [most likely predictions, 2nd most likely prediction, .... , 20th most likely prediction] <br>
# }

# %%
# convert the tcga data to features
tcga_abt = cde_data_modellers.create_base_for_unsupervised_learning(tcga_data)

tcga_predictions = model.predict_and_convert_to_json(tcga_abt)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 712/712 [00:00<00:00, 12517.95it/s]
#   0%|                                                                                          | 0/701 [00:00<?, ?it/s]
# Start converting descriptors to vectors
# Took 0.001064 minutes to vectorize the dataset
# Start converting descriptors to vectors
# 100%|███████████████████████████████████████████████████████████████████████████████| 701/701 [00:00<00:00, 780.10it/s]
# Took 0.015059 minutes to vectorize the dataset

# %% [markdown]
# ## Calculate accuracy of prediction

# %%
tcga_accuracy = ac.calculate_accuracy(tcga_data['gold_standard'],tcga_predictions)

# %%
tcga_accuracy
# Out:
# 0.4466994382022471

# %% [markdown]
# ## Test the model on the test dataset
#
# To do that, we shall first create the base table for the test dataset by parsing and indexing the test set in the same way as was done for the training set.

# %%
tdp1 = tdp.TCGA_data_processor(clinical_data_test_dir,False )
test_data = tdp1.get_parsed_data()
test_abt =cde_data_modellers.create_base_for_unsupervised_learning(test_data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 33.05it/s]
#  Processing clinical metadata.. please wait..
# 100%|█████████████████████████████████████████████████████████████████████████████| 225/225 [00:00<00:00, 16114.58it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 225/225 [00:00<00:00, 1895.82it/s]
# Start converting descriptors to vectors
# Took 0.000282 minutes to vectorize the dataset
# Start converting descriptors to vectors
# Took 0.002045 minutes to vectorize the dataset

# %% [markdown]
# ## Make predictions for the test dataset using the trained model

# %%
results = model.predict_and_convert_to_json(test_abt)

# %%
results
# Out:
# {'bcr_subject_code': ['4168555',
#   '6642901',
#   '2970589',
#   '3340437',
#   '2712076',
#   '5042478',
#   '2724803',
#   '2957317',
#   '2848548',
#   '6790551',
#   '5485932',
#   '6422470',
#   '3902309',
#   '2004085',
#   '58282',
#   '3347096',
#   '6411566',
#   '3734524',
#   '6260029',
#   '2712107'],
#  'subject_gender': ['5042480',
#   '2732976',
#   '2900244',
#   '2475573',
#   '5042478',
#   '4896072',
#   '2900209',
#   '2939287',
#   '2968264',
#   '6642901',
#   '2724803',
#   '2866635',
#   '6729517',
#   '2848548',
#   '4718874',
#   '2711762',
#   '6719499',
#   '3902309',
#   '3124770',
#   '3738935'],
#  'subject_race': ['2716767',
#   '3151100',
#   '3528623',
#   '5596079',
#   '2900209',
#   '3199145',
#   '6423062',
#   '2751416',
#   '2724803',
#   '2745086',
#   '6692002',
#   '2529067',
#   '6260029',
#   '2415070',
#   '2718840',
#   '6092251',
#   '3199148',
#   '6640209',
#   '6608480',
#   '2900244'],
#  'pharm_tx_mitotane_indicator': ['2438173',
#   '2608248',
#   '3738935',
#   '2529067',
#   '2848548',
#   '3902309',
#   '3734524',
#   '2475573',
#   '6422470',
#   '2998131',
#   '2997994',
#   '2724803',
#   '2919538',
#   '2475523',
#   '2553415',
#   '2672036',
#   '2678545',
#   '2735254',
#   '2969315',
#   '2708045'],
#  'pharm_tx_mitotane_theraputic_at_rec': ['2529067',
#   '6385381',
#   '2786019',
#   '2608248',
#   '2438173',
#   '3902309',
#   '6640209',
#   '2712290',
#   '2712095',
#   '3202583',
#   '2712076',
#   '6423056',
#   '2233003',
#   '2718840',
#   '6422470',
#   '6680272',
#   '2753012',
#   '2553415',
#   '3734524',
#   '2741564'],
#  'pharm_tx_mitotane_for_macro_disease': ['4478636',
#   '3646391',
#   '2786019',
#   '3915551',
#   '3902309',
#   '2783881',
#   '2184940',
#   '2234697',
#   '2529067',
#   '3005019',
#   '2590423',
#   '6680272',
#   '2003891',
#   '7185820',
#   '3233242',
#   '2004085',
#   '2608248',
#   '3915552',
#   '2712095',
#   '2711862'],
#  'pharm_tx_mitotane_theraputic_macro': ['2438173',
#   '2529067',
#   '2848548',
#   '2786019',
#   '3902309',
#   '6692791',
#   '2233003',
#   '3233242',
#   '2712095',
#   '2712290',
#   '3915551',
#   '2608248',
#   '2783881',
#   '2919538',
#   '2678422',
#   '5227882',
#   '6680272',
#   '2553415',
#   '6028532',
#   '2828444'],
#  'pharm_tx_mitotane_theraputic_at_prog': ['6385381',
#   '3202583',
#   '2529067',
#   '2741564',
#   '2741481',
#   '6640209',
#   '2753012',
#   '6692002',
#   '3902309',
#   '2794427',
#   '5069554',
#   '4718874',
#   '3830626',
#   '2608248',
#   '6790551',
#   '4277002',
#   '2712290',
#   '6680272',
#   '3734524',
#   '2625737'],
#  'ct_scan_preop_results.1': ['7072175',
#   '2751416',
#   '3865396',
#   '2004085',
#   '2752794',
#   '7072176',
#   '5042478',
#   '5581562',
#   '6640209',
#   '2003885',
#   '5042480',
#   '2459694',
#   '2717721',
#   '7147707',
#   '2634934',
#   '6260029',
#   '3412936',
#   '3915551',
#   '65302',
#   '2718241'],
#  'weiss_score_overall': ['3641045',
#   '3203343',
#   '4363067',
#   '4757169',
#   '2734788',
#   '4757153',
#   '4757113',
#   '3648744',
#   '2734693',
#   '5230734',
#   '3192892',
#   '5230732',
#   '5596079',
#   '3192947',
#   '4770759',
#   '3191997',
#   '2672075',
#   '4494162',
#   '6738206',
#   '4493982'],
#  'mitoses_per_50_hpf': ['3646391',
#   '3121372',
#   '2902574',
#   '3915551',
#   '3191976',
#   '3244154',
#   '2926001',
#   '4709530',
#   '5069554',
#   '4825031',
#   '6433397',
#   '2902598',
#   '4494162',
#   '7412743',
#   '2672122',
#   '2716767',
#   '7402818',
#   '7402811',
#   '3070892',
#   '2924335'],
#  'metastatic_tumor_site.1': ['3162641',
#   '3162636',
#   '3233242',
#   '3408572',
#   '3729998',
#   '3408682',
#   '2531939',
#   '2551893',
#   '5228950',
#   '3104403',
#   '3462302',
#   '4348005',
#   '3132899',
#   '3528004',
#   '3870453',
#   '3028697',
#   '6640209',
#   '3528003',
#   '3528034',
#   '3427609'],
#  'history_adrenal_hormone_excess': ['2752893',
#   '2007217',
#   '3203277',
#   '3347096',
#   '3440229',
#   '65065',
#   '2183392',
#   '64707',
#   '3006',
#   '2234697',
#   '5010431',
#   '3901800',
#   '4168569',
#   '2634934',
#   '3185116',
#   '5106131',
#   '7429172',
#   '3915552',
#   '3340437',
#   '3151106'],
#  'history_basis_adrenal_hormone_dx': ['3440229',
#   '3203277',
#   '2007217',
#   '65065',
#   '2752893',
#   '7147707',
#   '3414621',
#   '3028697',
#   '2784176',
#   '3347096',
#   '3233242',
#   '2922674',
#   '2234697',
#   '7429338',
#   '5543185',
#   '6755740',
#   '7429172',
#   '3006',
#   '3414617',
#   '6942211'],
#  'age_upon_diagnosis': ['2006657',
#   '3983612',
#   '3094883',
#   '3225640',
#   '4441704',
#   '2939739',
#   '3966995',
#   '3629993',
#   '3629991',
#   '6982687',
#   '3414503',
#   '6942753',
#   '3704297',
#   '6943594',
#   '2688921',
#   '2896960',
#   '3457768',
#   '3457771',
#   '3008273',
#   '3131740'],
#  'atypical_mitotic_figures': ['2429786',
#   '7185820',
#   '3227319',
#   '2521290',
#   '2784160',
#   '2431565',
#   '2783881',
#   '64773',
#   '5432636',
#   '2538825',
#   '2608165',
#   '2534588',
#   '3261557',
#   '2678446',
#   '2914029',
#   '2841253',
#   '2184940',
#   '3225971',
#   '5028033',
#   '3915551'],
#  'cytoplasm_presence_less_than_equal_25_percent': ['5010431',
#   '2924335',
#   '3261557',
#   '6826927',
#   '2183700',
#   '2590423',
#   '3028697',
#   '7372427',
#   '4887491',
#   '2841237',
#   '7092638',
#   '2926001',
#   '6640209',
#   '2815349',
#   '3646391',
#   '3244154',
#   '4709534',
#   '7382377',
#   '7093997',
#   '3203343'],
#  'diffuse_architecture': ['5543185',
#   '2711846',
#   '2712098',
#   '2914029',
#   '2711586',
#   '3441689',
#   '2712095',
#   '2712287',
#   '2534576',
#   '2783881',
#   '3233242',
#   '3261557',
#   '2590423',
#   '2650179',
#   '2669132',
#   '3143545',
#   '2711692',
#   '6692791',
#   '2711860',
#   '2241117'],
#  'invasion_of_tumor_capsule': ['7185820',
#   '57818',
#   '2783881',
#   '2590423',
#   '3028697',
#   '2536156',
#   '2614447',
#   '3915551',
#   '3143543',
#   '7382377',
#   '5028033',
#   '3427609',
#   '2521290',
#   '3132899',
#   '2551893',
#   '2431565',
#   '2968039',
#   '3915552',
#   '2968038',
#   '5543014'],
#  'mitotic_rate': ['4658096',
#   '2608165',
#   '5227882',
#   '2407022',
#   '2784160',
#   '2519467',
#   '2180403',
#   '3646391',
#   '2184940',
#   '2233003',
#   '3206020',
#   '2669789',
#   '3227319',
#   '2199571',
#   '7185820',
#   '2926001',
#   '5028033',
#   '2182386',
#   '2860221',
#   '58301'],
#  'necrosis': ['2841237',
#   '3227319',
#   '6755740',
#   '6982687',
#   '3436267',
#   '3233242',
#   '2841253',
#   '2551893',
#   '3086059',
#   '3646391',
#   '2006657',
#   '2866519',
#   '3380025',
#   '3261557',
#   '3523205',
#   '4168569',
#   '7074614',
#   '2678446',
#   '3527997',
#   '3527996'],
#  'nuclear_grade_III_IV': ['3646391',
#   '6680272',
#   '64773',
#   '2004146',
#   '5432636',
#   '3915551',
#   '2004085',
#   '2860221',
#   '4724991',
#   '4825031',
#   '2784160',
#   '3192274',
#   '58274',
#   '2184940',
#   '4724993',
#   '2234697',
#   '2180231',
#   '2003885',
#   '2431565',
#   '2723089'],
#  'ret': ['3440229',
#   '2803128',
#   '2783851',
#   '2783725',
#   '2900415',
#   '7147707',
#   '3623506',
#   '3430810',
#   '3151829',
#   '3',
#   '3086059',
#   '2553415',
#   '6074183',
#   '3086383',
#   '2752893',
#   '4843851',
#   '5858939',
#   '6640209',
#   '2721758',
#   '2708050'],
#  'sdha': ['3340437',
#   '2773146',
#   '2803128',
#   '2724803',
#   '3430945',
#   '2672070',
#   '3457768',
#   '2922674',
#   '3523205',
#   '3479270',
#   '3523210',
#   '3225640',
#   '3392464',
#   '3414609',
#   '3008233',
#   '2475553',
#   '3414503',
#   '4348005',
#   '3414617',
#   '3101898'],
#  'sdhaf2_sdh5': ['3340437',
#   '2773146',
#   '2803128',
#   '3457768',
#   '3101898',
#   '3430945',
#   '2724803',
#   '7092638',
#   '2672070',
#   '3008233',
#   '3479270',
#   '4736059',
#   '5543007',
#   '3523205',
#   '3414503',
#   '6826927',
#   '3392464',
#   '3523210',
#   '3414617',
#   '4348005'],
#  'sdhb': ['2773146',
#   '3340437',
#   '2724803',
#   '2803128',
#   '2672070',
#   '3101898',
#   '2922674',
#   '3430945',
#   '3457768',
#   '3413780',
#   '4736059',
#   '2848548',
#   '5543007',
#   '3101863',
#   '7092638',
#   '2224311',
#   '65302',
#   '6826927',
#   '3479270',
#   '3008233'],
#  'sdhc': ['2773146',
#   '2672070',
#   '3340437',
#   '2724803',
#   '3101898',
#   '2848548',
#   '2803128',
#   '3101863',
#   '3430945',
#   '2475553',
#   '3101416',
#   '3413780',
#   '4736059',
#   '2922674',
#   '3479270',
#   '3457768',
#   '6826927',
#   '3008233',
#   '2224311',
#   '5543007'],
#  'sdhd': ['2773146',
#   '3340437',
#   '2672070',
#   '2848548',
#   '2803128',
#   '2224311',
#   '2724803',
#   '3101898',
#   '4736059',
#   '3430945',
#   '5543007',
#   '3101863',
#   '6826927',
#   '6848664',
#   '2475553',
#   '3457768',
#   '7092638',
#   '3413780',
#   '6848655',
#   '3479270'],
#  'sinusoid_invasion': ['3143545',
#   '3143543',
#   '3276496',
#   '3273',
#   '6757524',
#   '2537017',
#   '2783739',
#   '2180778',
#   '5543185',
#   '5543014',
#   '2614447',
#   '2590423',
#   '3233242',
#   '2407022',
#   '3028697',
#   '65376',
#   '6755740',
#   '64202',
#   '2914029',
#   '3225971'],
#  'tmem127': ['4770795',
#   '6848664',
#   '7283979',
#   '3340437',
#   '4770793',
#   '3865396',
#   '6848655',
#   '2848548',
#   '4770759',
#   '3640742',
#   '5920728',
#   '4757199',
#   '3376324',
#   '4757231',
#   '4770797',
#   '6729517',
#   '5543638',
#   '2185832',
#   '5920723',
#   '3203343'],
#  'vhl': ['3101898',
#   '3101416',
#   '2752812',
#   '3101863',
#   '2475553',
#   '2672070',
#   '2553393',
#   '2438036',
#   '2773146',
#   '2784093',
#   '2708045',
#   '2783880',
#   '2772947',
#   '2900415',
#   '3102111',
#   '2513677',
#   '2783731',
#   '2534838',
#   '3430945',
#   '2534855'],
#  'weiss_venous_invasion': ['65376',
#   '3276496',
#   '5543185',
#   '2914029',
#   '64202',
#   '2180778',
#   '2004060',
#   '3143543',
#   '2590423',
#   '3028697',
#   '2519448',
#   '2718241',
#   '2972055',
#   '2537017',
#   '3006',
#   '2003891',
#   '2783881',
#   '6757524',
#   '3005391',
#   '2712076'],
#  'bcr_patient_code': ['5485932',
#   '3244747',
#   '3340437',
#   '3902309',
#   '4168555',
#   '3734524',
#   '3880845',
#   '2752748',
#   '7074614',
#   '3244154',
#   '2753012',
#   '2180638',
#   '2815349',
#   '7093997',
#   '3901799',
#   '2712076',
#   '4757231',
#   '4757199',
#   '7372427',
#   '2957317'],
#  'gender_of_patient': ['3244747',
#   '7074722',
#   '2939287',
#   '2180637',
#   '6035053',
#   '2180638',
#   '2229012',
#   '5485932',
#   '3902309',
#   '2199422',
#   '6640209',
#   '5042477',
#   '5042478',
#   '2672116',
#   '4363067',
#   '2900103',
#   '2180648',
#   '2415028',
#   '3244154',
#   '2672252'],
#  'race_of_patient': ['3244747',
#   '3199148',
#   '2745086',
#   '6640209',
#   '3429206',
#   '7074722',
#   '2180638',
#   '2719376',
#   '2751416',
#   '2229012',
#   '5858939',
#   '4171113',
#   '2180648',
#   '3430810',
#   '2180637',
#   '3902309',
#   '2234914',
#   '5042477',
#   '2871881',
#   '7372427'],
#  'live_birth_number': ['2486644',
#   '3171640',
#   '2896960',
#   '6931103',
#   '3087902',
#   '6931102',
#   '3025101',
#   '3132899',
#   '2939762',
#   '2751416',
#   '2745086',
#   '3185116',
#   '3440229',
#   '6942211',
#   '3008233',
#   '5543148',
#   '4461934',
#   '2955385',
#   '6982687',
#   '2923449'],
#  'patient_pregnancy_count': ['2180638',
#   '2180637',
#   '2180648',
#   '2183304',
#   '2261915',
#   '6316030',
#   '7425568',
#   '5485932',
#   '3244747',
#   '2745086',
#   '5152091',
#   '2229012',
#   '2815349',
#   '2719376',
#   '6035053',
#   '3199148',
#   '2939762',
#   '2753012',
#   '2415028',
#   '3440229'],
#  'pregnancies_count_total': ['6680272',
#   '6028532',
#   '2534619',
#   '2002839',
#   '3005019',
#   '3902309',
#   '2914029',
#   '2003891',
#   '2529242',
#   '3427609',
#   '3199148',
#   '6842068',
#   '2261915',
#   '2180805',
#   '4843851',
#   '2718241',
#   '3646391',
#   '2723089',
#   '5858939',
#   '6597613'],
#  'pregnancies_count_live_birth': ['2486644',
#   '2183304',
#   '2180638',
#   '7425568',
#   '2745086',
#   '2261915',
#   '2534617',
#   '2534618',
#   '5152091',
#   '3244747',
#   '3025101',
#   '4618491',
#   '3440229',
#   '3185116',
#   '5761990',
#   '4461934',
#   '2939762',
#   '7429172',
#   '3361460',
#   '5485932'],
#  'pregnancies_count_miscarriage': ['2860221',
#   '3131695',
#   '3144381',
#   '2794427',
#   '2799755',
#   '3028697',
#   '58301',
#   '2970589',
#   '3171875',
#   '3646391',
#   '5028033',
#   '64523',
#   '58271',
#   '7425568',
#   '57818',
#   '2534617',
#   '2718241',
#   '5823075',
#   '2003891',
#   '2669789'],
#  'pregnancies_count_induced_abortion': ['2180648',
#   '2180638',
#   '7425568',
#   '3734524',
#   '5152091',
#   '5485932',
#   '2180637',
#   '3427429',
#   '2261915',
#   '6035053',
#   '6316030',
#   '2815349',
#   '2753012',
#   '2852635',
#   '3902309',
#   '3294263',
#   '3199148',
#   '2784176',
#   '7372427',
#   '3086059'],
#  'pregnancies_count_ectopic': ['2261915',
#   '7425568',
#   '5152091',
#   '2180635',
#   '58274',
#   '2180638',
#   '2534617',
#   '2004085',
#   '2003891',
#   '2534618',
#   '3171875',
#   '2006107',
#   '3131695',
#   '2184940',
#   '2799755',
#   '4722743',
#   '2234697',
#   '3144381',
#   '2534619',
#   '2794427'],
#  'pregnancies_count_stillbirth': ['2183304',
#   '2180638',
#   '7425568',
#   '2261915',
#   '2745086',
#   '5823075',
#   '3199148',
#   '5152091',
#   '3340437',
#   '6423062',
#   '5485932',
#   '2732184',
#   '4843851',
#   '6316030',
#   '2180648',
#   '2180637',
#   '3812977',
#   '5316304',
#   '2234914',
#   '3202583'],
#  'pregnant_at_diagnosis': ['3901800',
#   '58318',
#   '3913864',
#   '4618491',
#   '3457771',
#   '3430945',
#   '3901798',
#   '3734524',
#   '58274',
#   '3901836',
#   '3880845',
#   '2922674',
#   '3901799',
#   '6982687',
#   '2625737',
#   '3225640',
#   '3523205',
#   '3462301',
#   '2922654',
#   '4277002'],
#  'history_immunosuppressive_disease': ['2784176',
#   '2753012',
#   '3101412',
#   '2752893',
#   '3005373',
#   '3414621',
#   '3414617',
#   '6385381',
#   '3203277',
#   '3414609',
#   '2625737',
#   '3457768',
#   '4887491',
#   '2645197',
#   '3233242',
#   '4529028',
#   '4618491',
#   '2852635',
#   '3462302',
#   '7074614'],
#  'other_immunosuppressive_disease': ['2784176',
#   '5485932',
#   '2179942',
#   '3462302',
#   '3282631',
#   '3462301',
#   '5629958',
#   '2753012',
#   '3414617',
#   '3408572',
#   '3414621',
#   '2815349',
#   '3165480',
#   '4887491',
#   '4529028',
#   '3527996',
#   '3414609',
#   '3086059',
#   '2556909',
#   '3233242'],
#  'age_when_diagnosed': ['4441704',
#   '3983612',
#   '3294402',
#   '2452836',
#   '2897006',
#   '6931084',
#   '7215679',
#   '3203343',
#   '5543007',
#   '3629993',
#   '3225640',
#   '6942753',
#   '2008468',
#   '2006650',
#   '3192947',
#   '2006657',
#   '3094883',
#   '2688921',
#   '3629991',
#   '4763851'],
#  'keratinization_squamous_cell': ['5028033',
#   '3151234',
#   '2841253',
#   '2429786',
#   '3206020',
#   '5432636',
#   '5010431',
#   '2783881',
#   '4851631',
#   '64707',
#   '3132903',
#   '3225971',
#   '2712095',
#   '6692791',
#   '2669132',
#   '5002071',
#   '3151235',
#   '2794427',
#   '3132899',
#   '2900103'],
#  'hysterectomy_Performed_Ind-3': ['6260029',
#   '4277002',
#   '6385038',
#   '3019419',
#   '4883996',
#   '58274',
#   '2871881',
#   '4155191',
#   '3687456',
#   '58318',
#   '2860221',
#   '58304',
#   '3030931',
#   '2625737',
#   '7290698',
#   '3192274',
#   '2914029',
#   '4722743',
#   '2003891',
#   '2787191'],
#  'hysterectomy_type': ['2783739',
#   '4353992',
#   '64206',
#   '2783754',
#   '3441689',
#   '2783789',
#   '3121491',
#   '2783735',
#   '2534598',
#   '64202',
#   '2536156',
#   '3431142',
#   '2914029',
#   '2783725',
#   '2534588',
#   '5543185',
#   '2783731',
#   '2519428',
#   '5543014',
#   '2678513'],
#  'other_hysterectomy_type': ['2783739',
#   '3427609',
#   '2536156',
#   '2711692',
#   '3431142',
#   '3441689',
#   '3427429',
#   '5543185',
#   '4353992',
#   '2783754',
#   '2783789',
#   '2322481',
#   '3462302',
#   '2200378',
#   '5543014',
#   '5485932',
#   '2914029',
#   '6028532',
#   '3121491',
#   '2534576'],
#  'margins_involved_hysterectomy': ['64206',
#   '2783739',
#   '64202',
#   '2914029',
#   '3233242',
#   '2002839',
#   '5543185',
#   '3427609',
#   '2783735',
#   '2783754',
#   '5936271',
#   '3261557',
#   '3086059',
#   '2615417',
#   '4883996',
#   '3132899',
#   '3687456',
#   '6757524',
#   '2431571',
#   '3086383'],
#  'other_involved_margins': ['3427609',
#   '2711692',
#   '3233242',
#   '3427429',
#   '2712253',
#   '2783754',
#   '2183700',
#   '2002839',
#   '5629958',
#   '3086059',
#   '5543185',
#   '2179942',
#   '3132899',
#   '2536156',
#   '64523',
#   '4168569',
#   '3261557',
#   '2534855',
#   '3086383',
#   '2615417'],
#  'pelvic_extension_comment': ['3104458',
#   '3104460',
#   '2615417',
#   '2452694',
#   '6757524',
#   '3151828',
#   '3427609',
#   '2743600',
#   '3276496',
#   '3143543',
#   '3151827',
#   '3086059',
#   '3151829',
#   '2590423',
#   '3143545',
#   '2783739',
#   '5543014',
#   '2182736',
#   '3151830',
#   '5543148'],
#  'lymphovascular_involvement': ['7346358',
#   '5581560',
#   '3104458',
#   '6757524',
#   '3276496',
#   '3143543',
#   '3151829',
#   '3151830',
#   '3143545',
#   '3233242',
#   '3104460',
#   '2914029',
#   '3',
#   '3151828',
#   '3086388',
#   '2534576',
#   '2952936',
#   '2180778',
#   '3151832',
#   '89'],
#  'corpus_involvement': ['7346358',
#   '3143545',
#   '3276496',
#   '6757524',
#   '65376',
#   '3143543',
#   '2537017',
#   '3151829',
#   '7063942',
#   '3273',
#   '3151831',
#   '3104458',
#   '2615417',
#   '3086383',
#   '3151830',
#   '2534576',
#   '2914029',
#   '2590423',
#   '89',
#   '3104460'],
#  'fedpet_or_ct_results': ['5042478',
#   '5042480',
#   '2645197',
#   '2634934',
#   '2752794',
#   '2004085',
#   '2003885',
#   '65065',
#   '2234697',
#   '2183392',
#   '2184940',
#   '3087902',
#   '3865396',
#   '2596499',
#   '2620279',
#   '5581562',
#   '2751416',
#   '2783725',
#   '4888611',
#   '4757199'],
#  'other_pos_node_location': ['2615417',
#   '2752618',
#   '3427609',
#   '3151831',
#   '57818',
#   '3151829',
#   '3151830',
#   '3151832',
#   '3104460',
#   '3086383',
#   '3151106',
#   '2431571',
#   '6757524',
#   '2002839',
#   '3408572',
#   '3086059',
#   '3233242',
#   '3132899',
#   '5543148',
#   '3086388'],
#  'lymph_nodes_supraclavicular': ['7346358',
#   '3104458',
#   '3104460',
#   '89',
#   '3',
#   '3151828',
#   '3151827',
#   '3151829',
#   '3276496',
#   '6757524',
#   '3143545',
#   '3151831',
#   '2914029',
#   '3151830',
#   '2900433',
#   '3086383',
#   '3151832',
#   '3151106',
#   '3086388',
#   '3143543'],
#  'cervix_suv_results': ['2431571',
#   '3151827',
#   '3',
#   '3151830',
#   '3151828',
#   '3104460',
#   '89',
#   '3151832',
#   '3151829',
#   '3104458',
#   '3086383',
#   '3086388',
#   '3107127',
#   '3151831',
#   '3087902',
#   '2827380',
#   '3132899',
#   '2721758',
#   '65065',
#   '2678491'],
#  'hpv_types_positive': ['3104403',
#   '3233649',
#   '3902309',
#   '3261557',
#   '2497209',
#   '2002839',
#   '2534855',
#   '2536156',
#   '4168569',
#   '3144381',
#   '6760770',
#   '6680272',
#   '2794427',
#   '2783881',
#   '2724803',
#   '3151234',
#   '58274',
#   '4851631',
#   '4168555',
#   '3107129'],
#  'hpv_types_other': ['5543007',
#   '2711692',
#   '2783881',
#   '3297383',
#   '2534855',
#   '6692791',
#   '5543316',
#   '4851631',
#   '3151234',
#   '3902309',
#   '3427429',
#   '3361460',
#   '2536156',
#   '2794427',
#   '2712095',
#   '3294402',
#   '3107129',
#   '2183700',
#   '5028033',
#   '3340437'],
#  'hpv_typing_method': ['2534838',
#   '3086383',
#   '3151831',
#   '3151829',
#   '5543198',
#   '3124770',
#   '3151832',
#   '2521657',
#   '3151830',
#   '3132899',
#   '3087902',
#   '2708050',
#   '2712095',
#   '2902574',
#   '3086388',
#   '2724803',
#   '2866635',
#   '5432636',
#   '6760770',
#   '2002839'],
#  'hpv_typing_method_other': ['3086383',
#   '2534838',
#   '3151831',
#   '3151829',
#   '2711692',
#   '3151830',
#   '3151832',
#   '3132899',
#   '2536156',
#   '2521657',
#   '3124770',
#   '2712095',
#   '3086388',
#   '3087902',
#   '64707',
#   '2712253',
#   '5432636',
#   '2002839',
#   '5028033',
#   '3427609'],
#  'pcr_primer_pairs': ['2199422',
#   '6423062',
#   '3025101',
#   '2745086',
#   '5042478',
#   '2902574',
#   '4888611',
#   '3340437',
#   '2712253',
#   '2712076',
#   '5042480',
#   '5106131',
#   '7372427',
#   '2902598',
#   '5596079',
#   '2957317',
#   '4718161',
#   '2827035',
#   '3865396',
#   '3165014'],
#  'pcr_primer_pairs_other': ['2199422',
#   '2712253',
#   '3025101',
#   '5106131',
#   '3340437',
#   '2179942',
#   '2745086',
#   '2752618',
#   '7425568',
#   '5042478',
#   '3429206',
#   '6423062',
#   '5485932',
#   '2902574',
#   '65302',
#   '2711692',
#   '3427429',
#   '5629958',
#   '3430810',
#   '5316304'],
#  'scca_tumor_marker': ['3162636',
#   '3162641',
#   '65302',
#   '3528004',
#   '7185820',
#   '7092638',
#   '4348005',
#   '3528003',
#   '3915552',
#   '4348007',
#   '3528020',
#   '3527996',
#   '3915551',
#   '3527990',
#   '3408572',
#   '3392464',
#   '2551893',
#   '3527997',
#   '4736059',
#   '65065'],
#  'days_to_diagnostic_mri_performed': ['6640209',
#   '3380025',
#   '6385381',
#   '3155365',
#   '3414608',
#   '2625737',
#   '3414503',
#   '3414554',
#   '3294402',
#   '6931170',
#   '3008333',
#   '2871881',
#   '7072175',
#   '3901799',
#   '3913864',
#   '3008313',
#   '2852635',
#   '3412936',
#   '3392465',
#   '2724416'],
#  'pregnant_at_diagnosis.1': ['3901800',
#   '58318',
#   '3913864',
#   '3901798',
#   '58274',
#   '3244154',
#   '4277002',
#   '3880845',
#   '3901799',
#   '3901836',
#   '3734524',
#   '2922654',
#   '3430945',
#   '3457771',
#   '2625737',
#   '2794427',
#   '3462301',
#   '7074614',
#   '4618491',
#   '6982687'],
#  'tumor_response': ['2551893',
#   '2464265',
#   '3527996',
#   '5629958',
#   '5228950',
#   '3729998',
#   '3162636',
#   '3527990',
#   '7092638',
#   '7185820',
#   '3427609',
#   '3436267',
#   '3527997',
#   '3162641',
#   '5010431',
#   '2183700',
#   '3528004',
#   '2536156',
#   '3528003',
#   '3870453'],
#  'bcr_subject_barcode': ['2712076',
#   '4168555',
#   '6642901',
#   '2957317',
#   '2970589',
#   '2233003',
#   '2848548',
#   '58282',
#   '6411566',
#   '3902309',
#   '2180231',
#   '2922674',
#   '2794427',
#   '2452190',
#   '6260029',
#   '2241117',
#   '7093997',
#   '6790551',
#   '3340437',
#   '3233649'],
#  'lymph_node_involvement_site': ['7346358',
#   '3',
#   '3104458',
#   '89',
#   '3151828',
#   '3104460',
#   '3276496',
#   '3151827',
#   '6757524',
#   '3233242',
#   '3151829',
#   '3151106',
#   '3151830',
#   '2914029',
#   '2431571',
#   '3151832',
#   '3151831',
#   '3086388',
#   '3086383',
#   '2002839'],
#  'extranodal_involvment_other': ['3233242',
#   '3104460',
#   '3104458',
#   '6757524',
#   '3427609',
#   '3151829',
#   '3151830',
#   '2615417',
#   '3086388',
#   '2914029',
#   '3151831',
#   '3086059',
#   '3151832',
#   '3086383',
#   '2537017',
#   '6074183',
#   '89',
#   '3441689',
#   '3151827',
#   '3276496'],
#  'extranodal_site_involvement': ['3233242',
#   '2914029',
#   '6757524',
#   '3143545',
#   '3276496',
#   '2537017',
#   '3086059',
#   '89',
#   '2615417',
#   '3151830',
#   '2180778',
#   '3104458',
#   '3441689',
#   '2002839',
#   '3151106',
#   '3151829',
#   '64206',
#   '7346358',
#   '3273',
#   '3151832'],
#  'follicular_component_percent': ['3261557',
#   '4709534',
#   '3132903',
#   '3913863',
#   '5010431',
#   '3132899',
#   '4353992',
#   '2590423',
#   '2497552',
#   '3225971',
#   '3028697',
#   '4709771',
#   '3087902',
#   '4709532',
#   '2743600',
#   '3151691',
#   '2841253',
#   '4709530',
#   '7093997',
#   '2536156'],
#  'gender_of_subject': ['7074722',
#   '2732976',
#   '5042477',
#   '2751416',
#   '5042478',
#   '2939287',
#   '3124768',
#   '5042480',
#   '2672083',
#   '2724803',
#   '6640209',
#   '2199422',
#   '3199145',
#   '6597613',
#   '3902309',
#   '7382377',
#   '2672275',
#   '4896072',
#   '6729517',
#   '7147707'],
#  'race_of_subject': ['2751416',
#   '2716767',
#   '7074722',
#   '3199145',
#   '5042477',
#   '2745086',
#   '3151100',
#   '6640209',
#   '2724803',
#   '5858939',
#   '3429206',
#   '6423062',
#   '5596079',
#   '3244747',
#   '2718840',
#   '6597613',
#   '2924335',
#   '3199148',
#   '2234914',
#   '5042478'],
#  'extranodal_lymphomatous_involvement': ['3233242',
#   '2914029',
#   '6757524',
#   '3151830',
#   '3151829',
#   '2537017',
#   '89',
#   '3276496',
#   '3104458',
#   '7346358',
#   '2180778',
#   '3086388',
#   '3151832',
#   '3143545',
#   '3151831',
#   '3086383',
#   '2534576',
#   '3913863',
#   '3104460',
#   '3427609'],
#  'ldh_norm_range_upper': ['3629987',
#   '2201886',
#   '2183392',
#   '2596499',
#   '3915552',
#   '2004086',
#   '3294416',
#   '3171875',
#   '3171861',
#   '3347096',
#   '2004060',
#   '65065',
#   '3629986',
#   '3413791',
#   '2007217',
#   '3413780',
#   '2003891',
#   '2634934',
#   '2234697',
#   '3915551'],
#  'bone_marrow_biopsy_performed': ['7290698',
#   '64507',
#   '2669786',
#   '2669788',
#   '58270',
#   '2669789',
#   '2783739',
#   '58271',
#   '2669787',
#   '5557173',
#   '58266',
#   '3131695',
#   '64773',
#   '58264',
#   '3131180',
#   '6692791',
#   '2783725',
#   '58262',
#   '58263',
#   '4851631'],
#  'bone_marrow_involvement': ['6757524',
#   '2669786',
#   '58270',
#   '6692791',
#   '7346358',
#   '3276496',
#   '64507',
#   '3143545',
#   '2669788',
#   '2669789',
#   '3233242',
#   '2669787',
#   '7290698',
#   '2827380',
#   '2537017',
#   '58271',
#   '2180778',
#   '2590423',
#   '3143543',
#   '58264'],
#  'bone_marrow_sample_histology': ['64773',
#   '3233242',
#   '2783881',
#   '2669788',
#   '3131180',
#   '2669789',
#   '2669786',
#   '2783880',
#   '64507',
#   '5432636',
#   '2452694',
#   '58271',
#   '2783725',
#   '7093997',
#   '2534576',
#   '5543014',
#   '5227882',
#   '58266',
#   '3162636',
#   '3131695'],
#  'immunopheotypic_analysis_tested': ['3151753',
#   '2712253',
#   '2711857',
#   '3121491',
#   '2922674',
#   '3151691',
#   '2712290',
#   '6953390',
#   '2712095',
#   '3107129',
#   '2678422',
#   '58274',
#   '2711692',
#   '2902574',
#   '58318',
#   '3302947',
#   '3233649',
#   '2006107',
#   '3302948',
#   '2900420'],
#  'immunophenotypic_analysis_method': ['5543198',
#   '6953390',
#   '2712290',
#   '2534838',
#   '2712095',
#   '2712253',
#   '3086383',
#   '2866635',
#   '3121491',
#   '3151831',
#   '2711695',
#   '3132899',
#   '3151753',
#   '2922674',
#   '3151829',
#   '64523',
#   '2529282',
#   '2678422',
#   '2711857',
#   '2529242'],
#  'immunopheotypic_analysis_results': ['3151753',
#   '2712253',
#   '2712095',
#   '2712290',
#   '2678422',
#   '64523',
#   '2902574',
#   '6953390',
#   '2922674',
#   '2711692',
#   '2708050',
#   '58291',
#   '2866635',
#   '5543198',
#   '2711857',
#   '58274',
#   '2787191',
#   '58318',
#   '2900420',
#   '2529282'],
#  'mib_1_positive_percent_range': ['2233003',
#   '2926001',
#   '4825031',
#   '3121491',
#   '3132903',
#   '6760770',
#   '3233649',
#   '3646391',
#   '3302948',
#   '2922654',
#   '3302947',
#   '6692791',
#   '2924335',
#   '3414613',
#   '3132899',
#   '6982687',
#   '2497552',
#   '4348005',
#   '4348007',
#   '3294402'],
#  'b_cell_genotype_method': ['3070892',
#   '3151234',
#   '2794427',
#   '3233649',
#   '5432636',
#   '2783881',
#   '2534838',
#   '3121491',
#   '2655822',
#   '6680272',
#   '5543198',
#   '6692791',
#   '58266',
#   '2712125',
#   '2180231',
#   '65302',
#   '2190',
#   '2860221',
#   '2429786',
#   '3206020'],
#  'igh_genotype_result': ['2724880',
#   '4168555',
#   '64523',
#   '2866635',
#   '4168569',
#   '3151753',
#   '2661682',
#   '5042478',
#   '2529232',
#   '2902574',
#   '3144381',
#   '2787191',
#   '2902598',
#   '3087902',
#   '2896998',
#   '2678446',
#   '2223863',
#   '2712290',
#   '3121491',
#   '2529242'],
#  'igk_genotype_result': ['2866635',
#   '64523',
#   '2787191',
#   '3121491',
#   '2724880',
#   '4168555',
#   '3144381',
#   '2902574',
#   '58266',
#   '5042478',
#   '58318',
#   '4168569',
#   '3151691',
#   '58291',
#   '2003891',
#   '3107129',
#   '2183392',
#   '3335773',
#   '64507',
#   '58274'],
#  'genetic_abnormality_tested': ['3151753',
#   '3151691',
#   '2223863',
#   '4168555',
#   '65302',
#   '3144381',
#   '3121491',
#   '3107129',
#   '7372427',
#   '2180255',
#   '3185116',
#   '64523',
#   '3302948',
#   '58266',
#   '2007217',
#   '64507',
#   '7093997',
#   '65065',
#   '6848664',
#   '3302947'],
#  'genetic_abnormality_tested_other': ['3151753',
#   '2223863',
#   '3151691',
#   '4168555',
#   '65302',
#   '5485932',
#   '3144381',
#   '64523',
#   '3185116',
#   '65065',
#   '3121491',
#   '2712253',
#   '2007217',
#   '3107129',
#   '64507',
#   '3915552',
#   '3915551',
#   '58266',
#   '2180255',
#   '2003891'],
#  'genetic_abnormality_method_other': ['2223863',
#   '3151831',
#   '3151753',
#   '3086383',
#   '64523',
#   '3151829',
#   '5543198',
#   '5485932',
#   '3151832',
#   '3132899',
#   '3427609',
#   '3151830',
#   '64707',
#   '3087902',
#   '65302',
#   '2534838',
#   '4168555',
#   '2529242',
#   '2431571',
#   '3144381'],
#  'genetic_abnormality_results': ['2223863',
#   '3151753',
#   '64523',
#   '3144381',
#   '4168555',
#   '65065',
#   '2724880',
#   '3151691',
#   '58271',
#   '65302',
#   '64507',
#   '5485932',
#   '2669788',
#   '3629987',
#   '3629986',
#   '2669786',
#   '2004085',
#   '2184940',
#   '2003885',
#   '2596499'],
#  'epstein_barr_viral_status': ['2922674',
#   '3233649',
#   '3413791',
#   '7093997',
#   '58266',
#   '3340437',
#   '4618491',
#   '4348005',
#   '2783725',
#   '3413780',
#   '4348007',
#   '3902309',
#   '3151832',
#   '2431571',
#   '3151830',
#   '3086388',
#   '2655822',
#   '3901825',
#   '3203277',
#   '3131180'],
#  'ebv_positive_malignant_cells_percent': ['3233649',
#   '3132903',
#   '3132899',
#   '5010431',
#   '64773',
#   '3729998',
#   '3151234',
#   '3261557',
#   '2841253',
#   '65302',
#   '2429786',
#   '3206020',
#   '2180710',
#   '2536156',
#   '5028033',
#   '2497552',
#   '3151753',
#   '2183700',
#   '64707',
#   '3913863'],
#  'ebv_status_malignan_cells_method': ['3233649',
#   '3151234',
#   '5028033',
#   '3132903',
#   '65302',
#   '3132899',
#   '64773',
#   '2429786',
#   '5432636',
#   '3297383',
#   '3206020',
#   '3427429',
#   '2848575',
#   '5227882',
#   '2233003',
#   '2655822',
#   '64707',
#   '2841253',
#   '2180710',
#   '3915552'],
#  'age_at_first_diagnosis': ['3983612',
#   '4441704',
#   '3094883',
#   '6931084',
#   '3225640',
#   '3629991',
#   '3294402',
#   '2897006',
#   '3457768',
#   '3165480',
#   '2625737',
#   '4887491',
#   '4618491',
#   '3392465',
#   '3131740',
#   '3008273',
#   '3414609',
#   '3392470',
#   '3440606',
#   '3008333'],
#  'genetic_abnormality_method_other.1': ['2223863',
#   '3151753',
#   '3151831',
#   '64523',
#   '3086383',
#   '3151829',
#   '5485932',
#   '3132899',
#   '3151832',
#   '5557173',
#   '4168555',
#   '3144381',
#   '5543198',
#   '65302',
#   '3087902',
#   '64707',
#   '2669788',
#   '64773',
#   '3427609',
#   '64507'],
#  'genetic_abnormality_results_other': ['2223863',
#   '3151753',
#   '64523',
#   '5485932',
#   '65065',
#   '3144381',
#   '4168555',
#   '64507',
#   '65302',
#   '2184940',
#   '2669788',
#   '58271',
#   '3629987',
#   '3185116',
#   '2669786',
#   '2234697',
#   '3915552',
#   '2007217',
#   '3915551',
#   '3151831'],
#  'init_pathology_dx_method_other': ['3462302',
#   '3462301',
#   '2431565',
#   '2752618',
#   '3408572',
#   '3427429',
#   '2655822',
#   '5432636',
#   '64773',
#   '3086383',
#   '5485932',
#   '3408682',
#   '3297383',
#   '2180710',
#   '6943594',
#   '3392464',
#   '5918245',
#   '3233242',
#   '3392470',
#   '3523205'],
#  'maximum_tumor_bulk_anatomic_site': ['3233242',
#   '5228950',
#   '2537017',
#   '64773',
#   '3870453',
#   '2180778',
#   '3427609',
#   '5227882',
#   '7185820',
#   '6640209',
#   '3132899',
#   '5918245',
#   '2590423',
#   '2848575',
#   '2707722',
#   '2614447',
#   '2914029',
#   '5543185',
#   '6757524',
#   '2716767'],
#  'patient_barcode': ['2688921',
#   '5543007',
#   '7318704',
#   '6931170',
#   '6029628',
#   '2815349',
#   '5543316',
#   '3094883',
#   '6029635',
#   '3155365',
#   '5002071',
#   '3294402',
#   '2180648',
#   '6942753',
#   '2798736',
#   '3244747',
#   '2753012',
#   '5485932',
#   '2752748',
#   '2180638'],
#  'patient_gender': ['2180637',
#   '2229012',
#   '649',
#   '2180648',
#   '2711762',
#   '2180638',
#   '651',
#   '2900103',
#   '3902309',
#   '6035053',
#   '5543014',
#   '2939287',
#   '2415028',
#   '3738935',
#   '4363067',
#   '3244747',
#   '3244154',
#   '4896072',
#   '6719502',
#   '6316030'],
#  'patient_race': ['3244747',
#   '3199148',
#   '649',
#   '2229012',
#   '2180637',
#   '651',
#   '2180648',
#   '4171113',
#   '7372427',
#   '2625737',
#   '2180638',
#   '3687456',
#   '2745086',
#   '2415070',
#   '3431142',
#   '6423062',
#   '2008468',
#   '3902309',
#   '6640209',
#   '3528623'],
#  'history_hematologic_disorder': ['2784176',
#   '2752893',
#   '3005391',
#   '3005373',
#   '2590423',
#   '3203277',
#   '3440229',
#   '3233242',
#   '2753012',
#   '2815349',
#   '7093997',
#   '5485932',
#   '2181650',
#   '7425568',
#   '3101412',
#   '2534576',
#   '3462302',
#   '7074614',
#   '3414613',
#   '2922674'],
#  'history_neoadjuvant_hydroxyurea_tx': ['2922674',
#   '6385381',
#   '2415070',
#   '2007217',
#   '5629886',
#   '6422470',
#   '2712290',
#   '2724416',
#   '2712107',
#   '2752893',
#   '2625737',
#   '3347096',
#   '4618491',
#   '2723089',
#   '6755740',
#   '2784176',
#   '2180231',
#   '3171861',
#   '5215480',
#   '6423056'],
#  'hydroxyurea_tx_days': ['7402811',
#   '4553741',
#   '4574698',
#   '4553775',
#   '4697591',
#   '5230734',
#   '4700318',
#   '4571745',
#   '4613676',
#   '3413780',
#   '2669688',
#   '2712107',
#   '4573669',
#   '5025021',
#   '7402818',
#   '4573664',
#   '2672031',
#   '4680991',
#   '5230732',
#   '4718161'],
#  'history_exposure_leukemogenic_agents': ['3629993',
#   '2415070',
#   '3629991',
#   '3199148',
#   '3294263',
#   '2718840',
#   '4171113',
#   '3006',
#   '2625737',
#   '2723089',
#   '2745086',
#   '3808803',
#   '2724416',
#   '7425568',
#   '3440229',
#   '3233242',
#   '2939739',
#   '2784176',
#   '5596079',
#   '6842068'],
#  'history_chemical_exposure_other': ['2784176',
#   '2752893',
#   '3101412',
#   '3440229',
#   '3203277',
#   '2590423',
#   '5629958',
#   '3185116',
#   '3427609',
#   '2939762',
#   '3527996',
#   '65065',
#   '3527990',
#   '3462302',
#   '3629993',
#   '2180637',
#   '3233242',
#   '2645197',
#   '5543014',
#   '2829812'],
#  'cells_used_for_analysis_source': ['3199148',
#   '2712253',
#   '5316304',
#   '2902574',
#   '5629958',
#   '6423062',
#   '7425568',
#   '4888611',
#   '2669678',
#   '3199145',
#   '6035053',
#   '3070892',
#   '6712200',
#   '5917270',
#   '6101184',
#   '2199422',
#   '3297383',
#   '6106656',
#   '2829753',
#   '2852635'],
#  'diagnosis_age': ['2006657',
#   '3225640',
#   '3094883',
#   '4441704',
#   '3983612',
#   '3629993',
#   '2939739',
#   '3629991',
#   '4618491',
#   '3457771',
#   '3966995',
#   '3457768',
#   '6943594',
#   '3131740',
#   '3414503',
#   '3430945',
#   '3462301',
#   '6982687',
#   '7215679',
#   '6931084'],
#  'percent_blasts_peripheral_blood': ['4851631',
#   '5010431',
#   '3983612',
#   '64773',
#   '5543139',
#   '64507',
#   '7093997',
#   '7290698',
#   '3206020',
#   '3107129',
#   '2688021',
#   '6101184',
#   '6692791',
#   '3010801',
#   '4353992',
#   '5543261',
#   '2669788',
#   '5543160',
#   '5543317',
#   '2182386'],
#  'fab_category': ['5106131',
#   '3070892',
#   '3648744',
#   '3901799',
#   '5485932',
#   '4757231',
#   '2181650',
#   '4770797',
#   '2957317',
#   '3199148',
#   '2655822',
#   '3901825',
#   '4825031',
#   '3440229',
#   '3340437',
#   '64834',
#   '2955385',
#   '3901800',
#   '7074614',
#   '3812977'],
#  'cyto_and_immuno_test_performed': ['7290698',
#   '2006107',
#   '64507',
#   '58304',
#   '2003891',
#   '2669786',
#   '58266',
#   '2190',
#   '58274',
#   '2669788',
#   '4277002',
#   '58271',
#   '58318',
#   '2180710',
#   '2007217',
#   '2669789',
#   '3131695',
#   '58301',
#   '3302947',
#   '58281'],
#  'cyto_and_immuno_test_percentage': ['7093997',
#   '7290698',
#   '2669788',
#   '58271',
#   '3151753',
#   '64507',
#   '3121491',
#   '58266',
#   '2669789',
#   '3302948',
#   '58262',
#   '3302947',
#   '3131695',
#   '2669786',
#   '3151691',
#   '2003891',
#   '3185116',
#   '2794427',
#   '3233649',
#   '3144381'],
#  'percent_cellularity': ['2784160',
#   '3225971',
#   '2841253',
#   '5010431',
#   '7093997',
#   '4709530',
#   '4709534',
#   '2841237',
#   '5028033',
#   '4709532',
#   '5002071',
#   '3151753',
#   '3366911',
#   '2815349',
#   '58282',
#   '58264',
#   '2669132',
#   '3238127',
#   '6692791',
#   '2183700'],
#  'wbc_24hr_of_banking': ['7074722',
#   '3294402',
#   '3366911',
#   '3121372',
#   '3070892',
#   '5042477',
#   '2751416',
#   '2553042',
#   '2669630',
#   '2738502',
#   '2902590',
#   '2519467',
#   '2953634',
#   '2939287',
#   '2957317',
#   '2926001',
#   '4255351',
#   '2897096',
#   '4763851',
#   '3704268'],
#  'hemoglobin_24hr_of_banking': ['3070892',
#   '2957317',
#   '3244747',
#   '6091415',
#   '2871881',
#   '3429206',
#   '5042477',
#   '2557832',
#   '2669588',
#   '2745086',
#   '2234914',
#   '2751416',
#   '2823938',
#   '3430810',
#   '5042478',
#   '2513839',
#   '2678491',
#   '2669600',
#   '2860221',
#   '2711792'],
#  'hematocrit_24hr_of_banking': ['2957317',
#   '3070892',
#   '2823938',
#   '2939287',
#   '2902590',
#   '2669588',
#   '7074722',
#   '2234914',
#   '5042477',
#   '2557832',
#   '2678491',
#   '2513839',
#   '2237974',
#   '3244747',
#   '3429206',
#   '2712199',
#   '6101184',
#   '2751416',
#   '3008933',
#   '6091415'],
#  'blast_count': ['3983612',
#   '2180635',
#   '2536156',
#   '2497209',
#   '58291',
#   '3131695',
#   '5485932',
#   '2183700',
#   '7382377',
#   '2415028',
#   '3427429',
#   '4441704',
#   '6760770',
#   '7290698',
#   '7185820',
#   '2261915',
#   '58282',
#   '2684395',
#   '2431565',
#   '3132899'],
#  'promyelocytes_count': ['2180635',
#   '58291',
#   '3131695',
#   '2497209',
#   '6760770',
#   '58271',
#   '3427429',
#   '2669788',
#   '6028532',
#   '3427609',
#   '2684395',
#   '3144381',
#   '5028033',
#   '58301',
#   '2669789',
#   '7425568',
#   '5485932',
#   '2860221',
#   '7185820',
#   '2732184'],
#  'myelocytes_24hr_of_banking': ['3366911',
#   '7074722',
#   '2237974',
#   '3070892',
#   '2957317',
#   '3429206',
#   '5042477',
#   '3297383',
#   '2897088',
#   '5097168',
#   '3087902',
#   '2829753',
#   '2751416',
#   '3025101',
#   '3430810',
#   '2939287',
#   '2829758',
#   '7092638',
#   '2233003',
#   '5028033'],
#  'metamyelocytes_24hr_of_banking': ['3070892',
#   '2237974',
#   '7074722',
#   '2957317',
#   '2829753',
#   '3366911',
#   '2829758',
#   '2751416',
#   '2553042',
#   '3025101',
#   '5042477',
#   '2513681',
#   '5227882',
#   '3087902',
#   '2233003',
#   '2860221',
#   '2970589',
#   '2794427',
#   '5028033',
#   '3429206'],
#  'bands_24hr_of_banking': ['2939287',
#   '2957317',
#   '7074613',
#   '5042477',
#   '7074722',
#   '4718161',
#   '5025021',
#   '3704268',
#   '3025101',
#   '2237974',
#   '3070892',
#   '2751416',
#   '2712199',
#   '3199145',
#   '3656876',
#   '4700318',
#   '4680991',
#   '2902598',
#   '5105654',
#   '2902590'],
#  'segs_24hr_of_banking': ['3294402',
#   '5042477',
#   '2939287',
#   '2902590',
#   '2669587',
#   '2237974',
#   '2957317',
#   '2711609',
#   '2902598',
#   '5543007',
#   '2557849',
#   '2669588',
#   '2712199',
#   '4763851',
#   '2513681',
#   '3704268',
#   '2672122',
#   '2711792',
#   '4700318',
#   '5218651'],
#  'basophils_count': ['58291',
#   '2230108',
#   '3087902',
#   '2497209',
#   '2960219',
#   '2180635',
#   '2407022',
#   '62590',
#   '2684395',
#   '64507',
#   '3131695',
#   '3395746',
#   '2732184',
#   '7064009',
#   '2222493',
#   '6942753',
#   '64523',
#   '61465',
#   '5557173',
#   '2871881'],
#  'basophils_count.1': ['2407022',
#   '2960219',
#   '3087902',
#   '58291',
#   '2497209',
#   '7405344',
#   '2230108',
#   '3395746',
#   '2684395',
#   '3005019',
#   '62590',
#   '2823938',
#   '2732184',
#   '64523',
#   '64507',
#   '3131695',
#   '2261915',
#   '5557173',
#   '2180635',
#   '3151828'],
#  'lymphocytes_count': ['2180635',
#   '58291',
#   '3151828',
#   '3131695',
#   '2684395',
#   '6760770',
#   '2497209',
#   '5028033',
#   '89',
#   '3086059',
#   '7185820',
#   '4851631',
#   '2669789',
#   '3151827',
#   '3144381',
#   '6028532',
#   '5557173',
#   '2536156',
#   '4441704',
#   '7425568'],
#  'monocytes_count': ['2180635',
#   '58291',
#   '3131695',
#   '6942753',
#   '6760770',
#   '4441704',
#   '58301',
#   '2003891',
#   '2233003',
#   '5917270',
#   '2718241',
#   '5557173',
#   '2497209',
#   '62590',
#   '3646391',
#   '6680272',
#   '2723089',
#   '3427429',
#   '2684395',
#   '6770855'],
#  'prolymphocytes_24hr_of_banking': ['5028033',
#   '2233003',
#   '5042477',
#   '3070892',
#   '2957317',
#   '2794427',
#   '3429206',
#   '7074722',
#   '2237974',
#   '2860221',
#   '3025101',
#   '2521290',
#   '3297383',
#   '3087902',
#   '2970589',
#   '3366911',
#   '6608480',
#   '3430810',
#   '3132899',
#   '2939287'],
#  'promonocytes_24hr_of_banking': ['7074722',
#   '3366911',
#   '3070892',
#   '2233003',
#   '5042477',
#   '3429206',
#   '2237974',
#   '6608480',
#   '2957317',
#   '2751416',
#   '3025101',
#   '3430810',
#   '2970589',
#   '2860221',
#   '5316304',
#   '2902598',
#   '4888611',
#   '2939287',
#   '3087902',
#   '6101184'],
#  'abnormal_lymphocyte_percent': ['3144381',
#   '3107129',
#   '5010431',
#   '2841253',
#   '6760770',
#   '3151753',
#   '3206020',
#   '4851631',
#   '2669789',
#   '6692791',
#   '5028033',
#   '3261557',
#   '2431565',
#   '3132903',
#   '64707',
#   '3151235',
#   '4168555',
#   '2669788',
#   '3131695',
#   '7093997'],
#  'cytogenetics_testing_performed': ['3121491',
#   '3151753',
#   '7290698',
#   '64507',
#   '2787191',
#   '2190',
#   '58266',
#   '2669786',
#   '2006107',
#   '3302948',
#   '4168555',
#   '3144381',
#   '5152091',
#   '3302947',
#   '64523',
#   '3132903',
#   '3132899',
#   '2866635',
#   '64707',
#   '58274'],
#  'metaphases_count': ['3151828',
#   '3151827',
#   '2684395',
#   '2222493',
#   '3',
#   '2230108',
#   '89',
#   '58291',
#   '64523',
#   '3427609',
#   '3131695',
#   '2180635',
#   '5823075',
#   '2431571',
#   '3086059',
#   '3162604',
#   '3629986',
#   '4168569',
#   '3427429',
#   '4843851'],
#  'cyto_risk_group': ['3244154',
#   '7290698',
#   '2900103',
#   '3132899',
#   '4277002',
#   '58282',
#   '2183700',
#   '3646391',
#   '58262',
#   '7382377',
#   '7093997',
#   '2669788',
#   '3151234',
#   '2180710',
#   '5010431',
#   '58281',
#   '3087902',
#   '3008933',
#   '5858939',
#   '2200378'],
#  'cyto_abnormality_type_other': ['3462297',
#   '3151753',
#   '2534855',
#   '3107129',
#   '5543007',
#   '5485932',
#   '2794427',
#   '2183700',
#   '3121491',
#   '2712253',
#   '3427429',
#   '2180710',
#   '3144381',
#   '6692791',
#   '7382377',
#   '2179942',
#   '7290698',
#   '3427609',
#   '3244154',
#   '2669132'],
#  'fish_performed_indicator': ['2534855',
#   '3734524',
#   '58274',
#   '2784176',
#   '5485932',
#   '3880845',
#   '64523',
#   '5152091',
#   '2190',
#   '3087902',
#   '2753012',
#   '3714486',
#   '2415028',
#   '3738935',
#   '58304',
#   '58318',
#   '2645197',
#   '3132899',
#   '3427429',
#   '6760770'],
#  'fish_abnormality_detected': ['3151691',
#   '3151753',
#   '2534855',
#   '6953390',
#   '4168555',
#   '2199422',
#   '2497209',
#   '64523',
#   '3144381',
#   '2223863',
#   '65302',
#   '2669132',
#   '3087902',
#   '7372427',
#   '3132899',
#   '5485932',
#   '2718854',
#   '3340437',
#   '3185116',
#   '3233649'],
#  'test_performed_indicator': ['3734524',
#   '5543342',
#   '58274',
#   '2708050',
#   '5338931',
#   '2190',
#   '7290698',
#   '2724880',
#   '2006107',
#   '2871881',
#   '2787191',
#   '2998131',
#   '58304',
#   '2180255',
#   '2003891',
#   '2645197',
#   '58318',
#   '2431571',
#   '3902309',
#   '3738935'],
#  'fish_performed_outcome': ['58304',
#   '2180403',
#   '58281',
#   '2190',
#   '2645197',
#   '61326',
#   '2794427',
#   '58318',
#   '6260029',
#   '2234697',
#   '2180444',
#   '6385038',
#   '5042478',
#   '58274',
#   '5557173',
#   '2180710',
#   '3880845',
#   '58270',
#   '3171861',
#   '3983612'],
#  'molecular_analysis_method_type': ['2534838',
#   '3151753',
#   '2223863',
#   '2712095',
#   '5543198',
#   '2529242',
#   '2712253',
#   '2708050',
#   '3132899',
#   '2519428',
#   '2711695',
#   '2783851',
#   '2756517',
#   '3086383',
#   '3151831',
#   '64523',
#   '2678574',
#   '2919538',
#   '2866635',
#   '2711692'],
#  'type_of_analysis_other': ['2712253',
#   '2529242',
#   '2756517',
#   '2519428',
#   '5485932',
#   '3430810',
#   '2711692',
#   '3429206',
#   '3427429',
#   '3124770',
#   '3734524',
#   '2534578',
#   '2919538',
#   '2866635',
#   '3087902',
#   '3132899',
#   '2521657',
#   '2613267',
#   '2534855',
#   '3902309'],
#  'molecular_abnormality_detected': ['2223863',
#   '3151753',
#   '64523',
#   '2669132',
#   '4168555',
#   '2534855',
#   '3144381',
#   '3151691',
#   '5485932',
#   '6953390',
#   '64707',
#   '2712233',
#   '5010431',
#   '2712253',
#   '3132899',
#   '2794427',
#   '2497209',
#   '2536156',
#   '2180710',
#   '2615417'],
#  'molecular_abnormality_results': ['2223863',
#   '3151753',
#   '64523',
#   '2712233',
#   '2724880',
#   '4168555',
#   '5485932',
#   '2711988',
#   '2708050',
#   '3144381',
#   '64707',
#   '65065',
#   '2431571',
#   '2007217',
#   '3151691',
#   '3087902',
#   '3629987',
#   '3132899',
#   '2615417',
#   '2513791'],
#  'molecular_abnormality_percent': ['3151753',
#   '2223863',
#   '5010431',
#   '2669132',
#   '3132899',
#   '3151691',
#   '64707',
#   '4168555',
#   '3087902',
#   '4709534',
#   '2615417',
#   '64523',
#   '5485932',
#   '7093997',
#   '2536156',
#   '4709530',
#   '2712253',
#   '3028697',
#   '57818',
#   '3261557'],
#  'atra_exposure': ['2200378',
#   '3629991',
#   '3687456',
#   '2625737',
#   '7406422',
#   '5581562',
#   '3151106',
#   '3104460',
#   '2723089',
#   '3104458',
#   '2829812',
#   '2590423',
#   '2407022',
#   '2452694',
#   '3629993',
#   '2718840',
#   '3005391',
#   '2002839',
#   '2234697',
#   '3019419'],
#  'diff_count_not_present_reason': ['3427429',
#   '2183700',
#   '2536156',
#   '2497209',
#   '3086059',
#   '7425568',
#   '3427609',
#   '2852635',
#   '2717721',
#   '2794427',
#   '5485932',
#   '5152091',
#   '2848575',
#   '5581562',
#   '6760770',
#   '2803128',
#   '3294263',
#   '2002839',
#   '7382377',
#   '3104403'],
#  'initial_pathologic_dx_days_to': ['3414554',
#   '3008313',
#   '3008333',
#   '3392464',
#   '3392465',
#   '3392470',
#   '3440606',
#   '3457768',
#   '3430945',
#   '3008273',
#   '3414617',
#   '3165475',
#   '3412936',
#   '3414503',
#   '3479270',
#   '3414621',
#   '3414609',
#   '3008335',
#   '3008233',
#   '3414608'],
#  'steroid_therapy_administered': ['4993836',
#   '3808803',
#   '4171113',
#   '3151106',
#   '2625737',
#   '5629958',
#   '3294263',
#   '3006',
#   '7063728',
#   '2859393',
#   '2415070',
#   '3188478',
#   '3151100',
#   '2179942',
#   '2442239',
#   '2741481',
#   '2741564',
#   '2724416',
#   '3238127',
#   '4709532'],
#  'bcr_pat_code': ['4825031',
#   '3340437',
#   '2970589',
#   '6260029',
#   '2233003',
#   '4168555',
#   '2922674',
#   '2712107',
#   '3413780',
#   '65302',
#   '6692791',
#   '6029635',
#   '2957317',
#   '2688921',
#   '2712076',
#   '5485932',
#   '2828444',
#   '2180231',
#   '3151832',
#   '4255351'],
#  'tumor_site': ['3162636',
#   '5228950',
#   '3233242',
#   '3162641',
#   '2551893',
#   '3729998',
#   '7185820',
#   '3874272',
#   '3104403',
#   '3527996',
#   '2531939',
#   '3528004',
#   '6640209',
#   '3527990',
#   '3427609',
#   '3227319',
#   '3527997',
#   '2536156',
#   '3528003',
#   '2590423'],
#  'supratentorial_localization': ['2783739',
#   '2534576',
#   '4851631',
#   '2743600',
#   '2871881',
#   '2590423',
#   '3010801',
#   '5010431',
#   '3431142',
#   '5543014',
#   '2815349',
#   '2753012',
#   '2608165',
#   '3687456',
#   '4171113',
#   '3143545',
#   '3915551',
#   '2786019',
#   '2645197',
#   '2184940'],
#  'gender_of_pat': ['5042477',
#   '2672083',
#   '7074722',
#   '3199145',
#   '2672261',
#   '2672246',
#   '6597613',
#   '3124768',
#   '5042478',
#   '6597601',
#   '6640209',
#   '2751416',
#   '2672075',
#   '2672252',
#   '2902598',
#   '2529242',
#   '6597605',
#   '2672116',
#   '2672122',
#   '2672275'],
#  'race_of_pat': ['3199145',
#   '2718840',
#   '2716767',
#   '5042477',
#   '3199148',
#   '2234914',
#   '2715645',
#   '2924335',
#   '3244747',
#   '6692002',
#   '2751416',
#   '6640209',
#   '3830626',
#   '6423062',
#   '2745086',
#   '2926001',
#   '3151100',
#   '6433397',
#   '7074722',
#   '6597613'],
#  'history_ionizing_rt_to_head': ['2955385',
#   '3188478',
#   '3006',
#   '5777505',
#   '2939762',
#   '3812977',
#   '7072175',
#   '2442239',
#   '3114013',
#   '3901800',
#   '6106656',
#   '3629993',
#   '2008468',
#   '7072176',
#   '3101412',
#   '3185116',
#   '2939739',
#   '3199148',
#   '4757231',
#   '2923449'],
#  'history_seizures': ['3101412',
#   '2752893',
#   '2784176',
#   '3203277',
#   '5596079',
#   '3005373',
#   '3005391',
#   '5106131',
#   '4757199',
#   '2590423',
#   '2442239',
#   '4757231',
#   '2181650',
#   '2608165',
#   '3440229',
#   '4168569',
#   '2955385',
#   '5775923',
#   '6597613',
#   '7382377'],
#  'history_headaches': ['3101412',
#   '3005391',
#   '2784176',
#   '3005373',
#   '2752893',
#   '2590423',
#   '3143545',
#   '5596079',
#   '4757231',
#   '4757199',
#   '2922674',
#   '2952936',
#   '2955385',
#   '2519448',
#   '4757113',
#   '3185116',
#   '3203277',
#   '5106131',
#   '5589757',
#   '4757169'],
#  'symp_changes_mental_status': ['4757199',
#   '2519448',
#   '2608165',
#   '4757231',
#   '5761990',
#   '4750941',
#   '4757169',
#   '4749879',
#   '4757113',
#   '2753012',
#   '3865396',
#   '3244747',
#   '2752893',
#   '2784176',
#   '2752794',
#   '7072142',
#   '5485932',
#   '5581560',
#   '4168569',
#   '3025101'],
#  'symp_changes_visual': ['6597601',
#   '2199422',
#   '6597613',
#   '3143545',
#   '2519448',
#   '4168569',
#   '2590423',
#   '2002839',
#   '6597605',
#   '3143543',
#   '4757199',
#   '4757231',
#   '5858939',
#   '3865396',
#   '7382377',
#   '4757113',
#   '5316304',
#   '5106131',
#   '3244747',
#   '6848655'],
#  'symp_changes_sensory': ['3865396',
#   '2608165',
#   '4757199',
#   '4757231',
#   '2590423',
#   '4770797',
#   '4757113',
#   '3005391',
#   '2752893',
#   '3005373',
#   '4770759',
#   '3101412',
#   '2519448',
#   '4770795',
#   '4757169',
#   '2784176',
#   '2669673',
#   '7072142',
#   '4750941',
#   '6719719'],
#  'symp_changes_motor_movement': ['7072142',
#   '2199422',
#   '2442239',
#   '3244747',
#   '4757231',
#   '4749879',
#   '4750941',
#   '5761990',
#   '2519448',
#   '4757199',
#   '4171113',
#   '6982687',
#   '4757113',
#   '4770797',
#   '2008468',
#   '2669673',
#   '5316304',
#   '6848655',
#   '2952936',
#   '2590423'],
#  'related_symptom_first_present': ['3203277',
#   '4887491',
#   '3171640',
#   '3440229',
#   '3028697',
#   '3408572',
#   '3165480',
#   '5485932',
#   '3462302',
#   '7092638',
#   '3414609',
#   '3408682',
#   '5010431',
#   '2669132',
#   '3462301',
#   '2179942',
#   '2536156',
#   '5761990',
#   '3966995',
#   '3008333'],
#  'first_symptom_longest_duration': ['3171640',
#   '2442239',
#   '3203277',
#   '2537017',
#   '2939762',
#   '4493982',
#   '4494162',
#   '3440229',
#   '4887491',
#   '3983612',
#   '4709530',
#   '2599988',
#   '2871831',
#   '5509574',
#   '3440307',
#   '3151100',
#   '4171113',
#   '2801908',
#   '3273',
#   '3191997'],
#  'history_asthma': ['3203277',
#   '2752893',
#   '3440229',
#   '3101412',
#   '2181650',
#   '3629993',
#   '3005373',
#   '3005391',
#   '2939739',
#   '2784176',
#   '2955385',
#   '2537017',
#   '2590423',
#   '5106131',
#   '5589757',
#   '7382377',
#   '3233242',
#   '3143545',
#   '3913863',
#   '3212030'],
#  'history_eczema': ['3101412',
#   '3203277',
#   '2752893',
#   '3629993',
#   '2784176',
#   '2181650',
#   '3440229',
#   '2537017',
#   '2955385',
#   '2939739',
#   '3233242',
#   '7382377',
#   '3005391',
#   '3005373',
#   '3143545',
#   '2590423',
#   '2756195',
#   '2829812',
#   '2180778',
#   '5106131'],
#  'histor_hay_fever': ['3101412',
#   '3629993',
#   '3812977',
#   '5775923',
#   '4757231',
#   '2955385',
#   '4757199',
#   '2939739',
#   '3629991',
#   '5777505',
#   '3114013',
#   '4757113',
#   '3714486',
#   '3624722',
#   '3203277',
#   '2923449',
#   '6597601',
#   '3203343',
#   '2669673',
#   '3624723'],
#  'history_dust_mold_allergy': ['3101412',
#   '2955385',
#   '3203277',
#   '2178045',
#   '2923449',
#   '5106131',
#   '3629993',
#   '2008468',
#   '2181650',
#   '3714486',
#   '5316304',
#   '5596079',
#   '2939739',
#   '6597601',
#   '2442239',
#   '3440229',
#   '6608480',
#   '2752893',
#   '2228610',
#   '3114013'],
#  'asthma_eczema_allergy_first_dx': ['3203277',
#   '3440229',
#   '3629993',
#   '3629991',
#   '2786019',
#   '3171640',
#   '2939739',
#   '3203343',
#   '2803128',
#   '7382377',
#   '3812977',
#   '2537017',
#   '3101412',
#   '3648744',
#   '3624722',
#   '4494162',
#   '5106131',
#   '3704268',
#   '2939762',
#   '6101184'],
#  'allergy_food_dx_indicator': ['6385381',
#   '2786019',
#   '2608248',
#   '3714486',
#   '6035053',
#   '3218999',
#   '2784176',
#   '2608196',
#   '2753012',
#   '2645197',
#   '6608480',
#   '3165014',
# ...
#   '6385381',
#   '2804953',
#   '3218999',
#   '2724803',
#   '2773146',
#   '2553415',
#   '6790551',
#   '6101184',
#   '6608480',
#   '2645197',
#   '3124770',
#   '2557849',
#   '3297383',
#   '6035053',
#   '2997994',
#   '2224341',
#   '6422470'],
#  'allergy_food_dx_age': ['6385381',
#   '2786019',
#   '3629993',
#   '6608480',
#   '5596079',
#   '3218999',
#   '3812977',
#   '7215679',
#   '6423056',
#   '2645197',
#   '3629991',
#   '2008468',
#   '6931130',
#   '6931125',
#   '2829812',
#   '3203343',
#   '7425568',
#   '2939739',
#   '2178045',
#   '6423062'],
#  'allergy_animals_insects_dx_indicator': ['6035053',
#   '3101412',
#   '3440229',
#   '3101416',
#   '6385381',
#   '3102072',
#   '5832571',
#   '2608196',
#   '6636215',
#   '6636216',
#   '2829753',
#   '3812977',
#   '2784176',
#   '2829758',
#   '2786019',
#   '3738935',
#   '3714486',
#   '3165014',
#   '3203277',
#   '2804953'],
#  'allergy_animals_insects_dx_type': ['3101412',
#   '3440229',
#   '6035053',
#   '2804953',
#   '3102072',
#   '5832571',
#   '2557849',
#   '2608196',
#   '3025101',
#   '3070892',
#   '3101416',
#   '2521661',
#   '3203277',
#   '3297383',
#   '2534578',
#   '2786019',
#   '2553415',
#   '6636215',
#   '6636216',
#   '6385381'],
#  'allergy_animals_insects_dx_age': ['3629993',
#   '5832571',
#   '3812977',
#   '3629991',
#   '2955385',
#   '3440229',
#   '4618491',
#   '3457768',
#   '3225640',
#   '2939739',
#   '3008273',
#   '3101412',
#   '3624722',
#   '6385381',
#   '3882972',
#   '2178045',
#   '2848528',
#   '3203277',
#   '6755740',
#   '2923449'],
#  'history_neoadjuvant_steroid_tx': ['2625737',
#   '2415070',
#   '3233242',
#   '3006',
#   '3151106',
#   '2723089',
#   '2922674',
#   '2741564',
#   '2007217',
#   '3347096',
#   '5629886',
#   '2752893',
#   '6755740',
#   '2741481',
#   '2718840',
#   '2234697',
#   '2753012',
#   '2652990',
#   '2003891',
#   '3171861'],
#  'history_neoadjuvant_medication': ['5629886',
#   '2415070',
#   '5629958',
#   '2784176',
#   '2625737',
#   '3294263',
#   '2752893',
#   '6385381',
#   '2724416',
#   '5215480',
#   '7382377',
#   '2741481',
#   '4277002',
#   '2179942',
#   '4718874',
#   '6035053',
#   '2745086',
#   '6423062',
#   '2753012',
#   '3165014'],
#  'family_history_brain_tumor': ['3203277',
#   '3440229',
#   '5010431',
#   '2590423',
#   '2669132',
#   '2537017',
#   '3913863',
#   '2752893',
#   '3233242',
#   '3132899',
#   '6692791',
#   '5106131',
#   '3143545',
#   '2534576',
#   '2955385',
#   '7382377',
#   '3729998',
#   '3171640',
#   '2939762',
#   '64707'],
#  'idh1_mutation_test_indicator': ['3151691',
#   '2438200',
#   '3151753',
#   '2534855',
#   '2669132',
#   '2708050',
#   '2848548',
#   '3121491',
#   '3738935',
#   '2998131',
#   '4168555',
#   '3734524',
#   '6260029',
#   '2787191',
#   '6953390',
#   '2866635',
#   '2645197',
#   '3865396',
#   '3132899',
#   '6422470'],
#  'idh1_mutation_test_method': ['3151691',
#   '3151831',
#   '3121491',
#   '3086383',
#   '3107129',
#   '3151753',
#   '2708050',
#   '2431571',
#   '3132899',
#   '3151832',
#   '3151829',
#   '5543198',
#   '2866635',
#   '3132903',
#   '3087902',
#   '2787191',
#   '6953390',
#   '64523',
#   '6260029',
#   '65302'],
#  'idh1_mutation_found': ['3865396',
#   '6260029',
#   '2829753',
#   '4722743',
#   '2970589',
#   '4277002',
#   '2829758',
#   '3192274',
#   '4724993',
#   '3087902',
#   '4168569',
#   '2712199',
#   '2926001',
#   '4888611',
#   '2438200',
#   '3132899',
#   '6042212',
#   '4724991',
#   '3238127',
#   '2756539'],
#  'inherited_genetic_syndrome_indicator': ['2784176',
#   '2534855',
#   '2223863',
#   '2753012',
#   '7093997',
#   '5485932',
#   '2815349',
#   '3151753',
#   '2794427',
#   '58264',
#   '3144381',
#   '58262',
#   '2752794',
#   '7290698',
#   '2669788',
#   '3734524',
#   '3738935',
#   '58271',
#   '2669132',
#   '2669789'],
#  'inherited_genetic_syndrome_specified': ['7093997',
#   '2794427',
#   '2180710',
#   '3151753',
#   '3144381',
#   '2784176',
#   '58281',
#   '58262',
#   '7290698',
#   '2534855',
#   '3233242',
#   '65065',
#   '2669788',
#   '58271',
#   '2223863',
#   '2669789',
#   '64507',
#   '58264',
#   '2669132',
#   '58304'],
#  'performance_status_days_to': ['3121372',
#   '3294402',
#   '6931170',
#   '4441704',
#   '2003853',
#   '5543007',
#   '6942753',
#   '3983612',
#   '6931084',
#   '2848575',
#   '6154730',
#   '6982687',
#   '88',
#   '6640209',
#   '4573669',
#   '2452836',
#   '5230732',
#   '2752794',
#   '4700318',
#   '2897006'],
#  'age_at_initial_diagnosis': ['3457768',
#   '2897006',
#   '4441704',
#   '3131740',
#   '3430945',
#   '3392465',
#   '3479270',
#   '3983612',
#   '4618491',
#   '3392470',
#   '3414503',
#   '3008233',
#   '6943594',
#   '3392464',
#   '3008313',
#   '3462301',
#   '3008273',
#   '3412936',
#   '3008333',
#   '3457771'],
#  'bcr_pat_barcode': ['2233003',
#   '4825031',
#   '2922674',
#   '3233649',
#   '6260029',
#   '2970589',
#   '2712076',
#   '3413780',
#   '2957317',
#   '4168555',
#   '2180231',
#   '5917270',
#   '3413791',
#   '2828444',
#   '6433397',
#   '2902574',
#   '2233052',
#   '2926001',
#   '2199571',
#   '65302'],
#  'pat_race': ['6692002',
#   '7405344',
#   '3830626',
#   '2718840',
#   '2716767',
#   '2715645',
#   '4825031',
#   '6433397',
#   '3199145',
#   '3199148',
#   '1515',
#   '3528623',
#   '3687456',
#   '6260029',
#   '6423062',
#   '6706643',
#   '2924335',
#   '2859393',
#   '3629991',
#   '3151100'],
#  'history_of_undescended_testis': ['3203277',
#   '3440229',
#   '5106131',
#   '2786019',
#   '4171113',
#   '3244747',
#   '2752893',
#   '4757199',
#   '2590423',
#   '2827380',
#   '3431142',
#   '4757231',
#   '2716767',
#   '2615417',
#   '3143545',
#   '3028697',
#   '4736059',
#   '4757113',
#   '57818',
#   '3528623'],
#  'level_of_non_descent': ['5581562',
#   '2871881',
#   '6826927',
#   '2743600',
#   '3028697',
#   '2786019',
#   '2924335',
#   '2716767',
#   '4709534',
#   '5485932',
#   '4709771',
#   '3244747',
#   '4757199',
#   '3431142',
#   '2926001',
#   '2615417',
#   '2952936',
#   '2513796',
#   '5038571',
#   '2803128'],
#  'undescended_testis_corrected': ['6074183',
#   '3431142',
#   '2827380',
#   '3528623',
#   '3687456',
#   '3302947',
#   '3302948',
#   '3121491',
#   '2827051',
#   '2615417',
#   '4736059',
#   '2180255',
#   '4171113',
#   '5936271',
#   '5338931',
#   '6848655',
#   '2629105',
#   '4843851',
#   '6848664',
#   '4709534'],
#  'undescended_testis_corrected_age': ['3687456',
#   '3007538',
#   '3629991',
#   '3528623',
#   '5936271',
#   '3629993',
#   '3302948',
#   '3302947',
#   '2939739',
#   '2827380',
#   '4348007',
#   '4709534',
#   '3203277',
#   '3431142',
#   '4348005',
#   '3566839',
#   '6848655',
#   '2180255',
#   '4171113',
#   '3212030'],
#  'undescended_testis_method_left': ['3151831',
#   '3086383',
#   '3151829',
#   '7346358',
#   '3151830',
#   '3151832',
#   '6074183',
#   '6091415',
#   '3577251',
#   '3438723',
#   '2180139',
#   '2615417',
#   '3086388',
#   '3104460',
#   '2002839',
#   '3276496',
#   '6757524',
#   '2827380',
#   '2914029',
#   '2952936'],
#  'undescended_testis_method_right': ['3151831',
#   '3086383',
#   '3151832',
#   '3151829',
#   '3151830',
#   '6074183',
#   '2615417',
#   '3086388',
#   '7346358',
#   '3104460',
#   '2180139',
#   '2002839',
#   '57818',
#   '2431571',
#   '2241117',
#   '6091415',
#   '2952936',
#   '3151827',
#   '3244747',
#   '3276496'],
#  'history_hypospadias': ['2752893',
#   '2415070',
#   '2590423',
#   '3005391',
#   '5010431',
#   '3006',
#   '3005373',
#   '2537017',
#   '2784176',
#   '3440229',
#   '3203277',
#   '4993836',
#   '7382377',
#   '3629993',
#   '7063942',
#   '5589757',
#   '3101412',
#   '2741481',
#   '3808803',
#   '3143545'],
#  'history_fertility': ['2752893',
#   '3812977',
#   '3101412',
#   '2784176',
#   '2711988',
#   '2939739',
#   '5653757',
#   '2181650',
#   '2955385',
#   '2442239',
#   '2645197',
#   '6035053',
#   '5775923',
#   '2871831',
#   '3203277',
#   '3440229',
#   '2786019',
#   '7382377',
#   '5596079',
#   '2923449'],
#  'family_history_testicular_cancer': ['3203277',
#   '3440229',
#   '3913863',
#   '2669132',
#   '3028697',
#   '5761990',
#   '3171640',
#   '3966995',
#   '2431565',
#   '5106131',
#   '6692791',
#   '2534576',
#   '64707',
#   '2752893',
#   '3812977',
#   '4757169',
#   '2538825',
#   '4757113',
#   '7093997',
#   '57818'],
#  'relation_testicular_cancer': ['3913863',
#   '3440229',
#   '3171640',
#   '3966995',
#   '3028697',
#   '3203277',
#   '7093997',
#   '5761990',
#   '3462302',
#   '3441689',
#   '6943594',
#   '2669132',
#   '2536156',
#   '4461934',
#   '3408572',
#   '2534617',
#   '4353992',
#   '3414613',
#   '4887491',
#   '2827380'],
#  'family_history_other_cancer': ['3203277',
#   '3440229',
#   '5106131',
#   '2431565',
#   '3812977',
#   '3171640',
#   '2669132',
#   '2179942',
#   '3028697',
#   '2784176',
#   '5629958',
#   '2752893',
#   '3101412',
#   '5485932',
#   '3462302',
#   '3714486',
#   '3913863',
#   '2939762',
#   '6942211',
#   '7382377'],
#  'relative_family_cancer_hx_text': ['3203277',
#   '3171640',
#   '2669132',
#   '3440229',
#   '3132899',
#   '5761990',
#   '3729998',
#   '2431565',
#   '3812977',
#   '2536156',
#   '2900103',
#   '3966995',
#   '5028033',
#   '5485932',
#   '3028697',
#   '2229012',
#   '2752618',
#   '3233242',
#   '2848528',
#   '3087902'],
#  'postoperative_tx': ['2620279',
#   '2752794',
#   '6640209',
#   '2669688',
#   '5832571',
#   '4348007',
#   '2829753',
#   '4348005',
#   '6385381',
#   '2957317',
#   '2712290',
#   '5042480',
#   '2669630',
#   '2829758',
#   '2711862',
#   '6636216',
#   '6636215',
#   '2620271',
#   '4887491',
#   '6755740'],
#  'bilateral_diagnosis_timing_type': ['2513796',
#   '2180637',
#   '3440229',
#   '3203277',
#   '3025101',
#   '3124770',
#   '3913863',
#   '2557849',
#   '2711988',
#   '2939762',
#   '3729998',
#   '3244747',
#   '2900103',
#   '3966995',
#   '5543014',
#   '2200378',
#   '2650179',
#   '2866635',
#   '2229012',
#   '2180648'],
#  'synchronous_tumor_histology_type': ['3729998',
#   '2534588',
#   '3913863',
#   '2783881',
#   '3225971',
#   '5432636',
#   '2429786',
#   '3151234',
#   '2538825',
#   '3162641',
#   '2783731',
#   '5543014',
#   '3233242',
#   '3441689',
#   '5228950',
#   '2841253',
#   '3523210',
#   '2534576',
#   '3203277',
#   '3162636'],
#  'synchronous_tumor_histology_pct': ['3729998',
#   '3913863',
#   '3025101',
#   '2783881',
#   '7093997',
#   '3203277',
#   '5228950',
#   '5432636',
#   '3233242',
#   '5543014',
#   '65302',
#   '3225971',
#   '3527996',
#   '3441689',
#   '3162641',
#   '3162636',
#   '2650179',
#   '3151234',
#   '3528004',
#   '3440229'],
#  'testis_tumor_macroextent': ['3225971',
#   '3729998',
#   '3913863',
#   '5228950',
#   '2551893',
#   '3162641',
#   '2531939',
#   '2590423',
#   '2914029',
#   '3162636',
#   '3441689',
#   '2183700',
#   '3233242',
#   '3427609',
#   '2537017',
#   '3151234',
#   '3870453',
#   '65065',
#   '3523205',
#   '65302'],
#  'testis_tumor_macroextent_other': ['3225971',
#   '2183700',
#   '5228950',
#   '3427609',
#   '3729998',
#   '2551893',
#   '3913863',
#   '3233242',
#   '3162641',
#   '3441689',
#   '3151234',
#   '2537017',
#   '2914029',
#   '65065',
#   '3162636',
#   '2536156',
#   '3523205',
#   '2590423',
#   '7185820',
#   '65302'],
#  'testis_tumor_microextent': ['3225971',
#   '3162641',
#   '2531939',
#   '3729998',
#   '3913863',
#   '3151234',
#   '5228950',
#   '2551893',
#   '3162636',
#   '2537017',
#   '6692791',
#   '65065',
#   '3874272',
#   '3870453',
#   '2429786',
#   '3132899',
#   '64215',
#   '3132903',
#   '2183700',
#   '2590423'],
#  'histologic_diagnosis_percent': ['3729998',
#   '3913863',
#   '3227319',
#   '3523205',
#   '5543316',
#   '3966995',
#   '3462301',
#   '6943594',
#   '2841237',
#   '4887491',
#   '3523210',
#   '3430945',
#   '5543014',
#   '3414608',
#   '3462297',
#   '3233242',
#   '3457771',
#   '5543160',
#   '2431565',
#   '3203277'],
#  'intratubular_germ_cell_neoplasm': ['2841253',
#   '2429786',
#   '3225971',
#   '5028033',
#   '2783881',
#   '3206020',
#   '3151234',
#   '64773',
#   '6692791',
#   '5010431',
#   '2784160',
#   '3227319',
#   '2431565',
#   '5432636',
#   '58282',
#   '3233649',
#   '3028697',
#   '3729998',
#   '58262',
#   '2794427'],
#  'serum_markers': ['4348005',
#   '4348007',
#   '2199571',
#   '2182386',
#   '3629985',
#   '3574943',
#   '3629986',
#   '3629987',
#   '2827051',
#   '2827380',
#   '65065',
#   '5228950',
#   '2004086',
#   '2669788',
#   '58266',
#   '64507',
#   '2003885',
#   '58291',
#   '5227882',
#   '3413791'],
#  'pre_orchi_hcg': ['3233649',
#   '3901798',
#   '3413780',
#   '3294402',
#   '4348005',
#   '3901824',
#   '3915552',
#   '65302',
#   '3901799',
#   '3901823',
#   '3302955',
#   '3901800',
#   '3413791',
#   '3070892',
#   '2922674',
#   '3913864',
#   '65065',
#   '2183392',
#   '3901825',
#   '3901836'],
#  'pre_orchi_afp': ['2897006',
#   '4348005',
#   '3901798',
#   '3294402',
#   '6931170',
#   '3901800',
#   '3901799',
#   '3901824',
#   '4348007',
#   '3915552',
#   '3913864',
#   '65302',
#   '3121372',
#   '3901836',
#   '3302947',
#   '3070892',
#   '3233649',
#   '3901823',
#   '3901825',
#   '3413780'],
#  'pre_orchi_lh': ['3901798',
#   '3901824',
#   '4348005',
#   '3901799',
#   '3915552',
#   '3913864',
#   '3901800',
#   '3302955',
#   '3070892',
#   '65302',
#   '3302947',
#   '3233649',
#   '3901836',
#   '3413780',
#   '3901823',
#   '3901825',
#   '3413791',
#   '3901839',
#   '4348007',
#   '2183392'],
#  'pre_orchi_testosterone': ['3913864',
#   '3901839',
#   '3901800',
#   '3901798',
#   '3901799',
#   '3901836',
#   '3901824',
#   '3901823',
#   '4348005',
#   '3302947',
#   '3901825',
#   '4348007',
#   '3233649',
#   '2922674',
#   '3302948',
#   '7429172',
#   '65065',
#   '4353992',
#   '7429338',
#   '2183392'],
#  'post_orchi_ldh': ['6942753',
#   '3294402',
#   '6931170',
#   '6931084',
#   '2897006',
#   '3901836',
#   '3901823',
#   '3901824',
#   '65302',
#   '3901839',
#   '3983612',
#   '2688921',
#   '3901800',
#   '3901825',
#   '3901798',
#   '3121372',
#   '3913864',
#   '3915552',
#   '3901799',
#   '4348007'],
#  'post_orchi_hcg': ['3901836',
#   '65302',
#   '3901824',
#   '3901823',
#   '3901825',
#   '3070892',
#   '3901839',
#   '3233649',
#   '3901798',
#   '3901800',
#   '3901799',
#   '3915552',
#   '4348007',
#   '3913864',
#   '4348005',
#   '3915551',
#   '6931170',
#   '4825031',
#   '6942753',
#   '2712233'],
#  'post_orchi_afp': ['3901836',
#   '2897006',
#   '6931170',
#   '4348007',
#   '3901824',
#   '3901800',
#   '65302',
#   '3901825',
#   '3901798',
#   '3070892',
#   '3901839',
#   '3121372',
#   '4348005',
#   '3901799',
#   '3901823',
#   '6942753',
#   '3913864',
#   '3915552',
#   '6931084',
#   '3440606'],
#  'post_orchi_lh': ['3901836',
#   '3901824',
#   '3901839',
#   '3901825',
#   '3070892',
#   '3901823',
#   '65302',
#   '3901800',
#   '4348007',
#   '3901799',
#   '3901798',
#   '3913864',
#   '3915552',
#   '4348005',
#   '3302956',
#   '3302948',
#   '3528020',
#   '3915551',
#   '3225640',
#   '4825031'],
#  'post_orchi_testosterone': ['3901839',
#   '3901836',
#   '3913864',
#   '3901825',
#   '3901823',
#   '3901800',
#   '3901824',
#   '3901799',
#   '4348007',
#   '3901798',
#   '4348005',
#   '3302948',
#   '65302',
#   '3302947',
#   '2007217',
#   '3966995',
#   '3414608',
#   '7429172',
#   '4709530',
#   '3225640'],
#  'first_treatment_success': ['2939762',
#   '3171640',
#   '2744948',
#   '2599988',
#   '3165480',
#   '2180648',
#   '4887491',
#   '7092638',
#   '3429206',
#   '3151100',
#   '2599994',
#   '3430810',
#   '5629958',
#   '2745086',
#   '2199422',
#   '2180637',
#   '2553429',
#   '3440606',
#   '3440229',
#   '3203343'],
#  'igcccg_stage': ['3347096',
#   '4724991',
#   '3104403',
#   '3192274',
#   '3151691',
#   '4277002',
#   '6260029',
#   '3101898',
#   '2634934',
#   '65302',
#   '3131180',
#   '2232784',
#   '2183392',
#   '2655822',
#   '61326',
#   '4724993',
#   '2787191',
#   '58266',
#   '58318',
#   '2006107'],
#  'days_to_bilateral_tumor_dx': ['7092638',
#   '3527990',
#   '6640209',
#   '3294402',
#   '3392464',
#   '4348005',
#   '3527996',
#   '3915552',
#   '3523210',
#   '3527997',
#   '3523205',
#   '7147707',
#   '65065',
#   '4888611',
#   '7072175',
#   '4348007',
#   '3008333',
#   '7429172',
#   '3188478',
#   '2827051'],
#  'diagnosed_age': ['2006657',
#   '6931084',
#   '3225640',
#   '3629993',
#   '3629991',
#   '3094883',
#   '2688921',
#   '4441704',
#   '7215679',
#   '3687456',
#   '3414503',
#   '3131740',
#   '3457768',
#   '2897006',
#   '6942753',
#   '2006650',
#   '6931125',
#   '4887491',
#   '6931170',
#   '2625737'],
#  'days_to_pre_orchi_serum_test': ['4348005',
#   '4348007',
#   '3294402',
#   '3302947',
#   '65065',
#   '7429172',
#   '65302',
#   '3302948',
#   '3901798',
#   '3901799',
#   '7429338',
#   '5832571',
#   '3414608',
#   '3913864',
#   '2007217',
#   '3915552',
#   '2922674',
#   '2596499',
#   '4461934',
#   '2848528'],
#  'days_to_post_orchi_serum_test': ['3294402',
#   '6931170',
#   '6942753',
#   '4348007',
#   '4348005',
#   '6931084',
#   '3121372',
#   '2897006',
#   '65302',
#   '2897096',
#   '3983612',
#   '3302948',
#   '3302947',
#   '3414608',
#   '2007217',
#   '3901799',
#   '7429172',
#   '3913864',
#   '5025021',
#   '4441704'],
#  'pat_gender': ['2672122',
#   '2672252',
#   '6712200',
#   '2672083',
#   '2672261',
#   '2902598',
#   '2672246',
#   '3199145',
#   '6738185',
#   '2221338',
#   '6719502',
#   '5042477',
#   '3070892',
#   '2200378',
#   '2521657',
#   '4718161',
#   '6706643',
#   '4825031',
#   '2866635',
#   '2672036'],
#  'lymphovascular_invasion_present': ['3143543',
#   '5543014',
#   '3086059',
#   '3143545',
#   '2783881',
#   '57818',
#   '2866519',
#   '2784160',
#   '2431565',
#   '3233242',
#   '2783739',
#   '2590423',
#   '2669789',
#   '5543185',
#   '2429786',
#   '3028697',
#   '2431571',
#   '5543148',
#   '2180778',
#   '7093997']}

# %% [markdown]
# # Calculate accuracy of prediction for the test dataset
#
# Note that the participants won't have access to the gold standard data, therefore won't be able to perform the following step. However, participants can divide the training data in to train, test, validation sets and perform the following on the test data.

# %%
test_gs = {}
with open(test_gold_standard, 'rb') as file:
    test_gs = json.load(file)
test_accuracy = ac.calculate_accuracy(test_gs,results)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-04e33ab9d3ba> in <module>
#       1 test_gs = {}
# ----> 2 with open(test_gold_standard, 'rb') as file:
#       3     test_gs = json.load(file)
#       4 test_accuracy = ac.calculate_accuracy(test_gs,results)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gold_standard/test_gs.json'

# %%
test_accuracy
# Out:
# 0.0951111111111111

# %% [markdown]
# ## Log model, model parameters etc. using mlflow
#
# This will ensure reproducibility of results and will keep track of all models and results during the model development and calibration.

# %%
with mlflow.start_run():
    # print out current run_uuid
    run_uuid = mlflow.active_run().info.run_uuid
    print("MLflow Run ID: %s" % run_uuid)
    
    # log parameters
    mlflow.log_param("window_size", params["fasttext"]["window"])
    mlflow.log_param("min_count", params["fasttext"]["min_count"])
    mlflow.log_param("epochs", params["fasttext"]["epochs"])
    mlflow.log_param("vector_size", params["fasttext"]["vector_size"])
      
    mlflow.log_param("model_type", params['model']["name"])
    
    for k in params['model']['model_params'].keys():
        mlflow.log_param("model_params_"+k, params['model']["model_params"][k])
    
    # log metrics
    mlflow.log_metric('train_accuracy',tcga_accuracy)    
    mlflow.log_metric("test_accuracy",test_accuracy)
    
    #mlflow.sklearn.logmodel()
    with open('models/'+run_uuid+'.pkl','wb') as file:
        pickle.dump(model, file)
    
    mlflow.end_run()
# Out:
# MLflow Run ID: 7927668ee0c241268d84b08ed3f5722b

# %% [markdown]
# ### Use mlflow to track models

# %% [markdown]
# <img src="img/mlflow_ui.png">

# %%
# !mlflow ui

# %% [markdown]
# ### To view mlflow ui go to http://localhost:5000
